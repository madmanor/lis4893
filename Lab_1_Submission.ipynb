# %% [markdown]
# <a href="https://colab.research.google.com/github/madmanor/lis4893/blob/main/Lab_1_Submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)

# %%
import requests
import os
import json

# %%
params = {
    "api_key": SERPAPI_API_KEY,
    "engine": "youtube_video_transcript",
    "v": "BzTdcoUSgaA&t=13620s",
    "type": "asr"
}

# %%
search = requests.get("https://serpapi.com/search", params=params)
response = search.json()

print(json.dumps(response, indent=2))
# Out:
# {
#   "search_metadata": {
#     "id": "69dff9dffdfbab3bc1a2f4e1",
#     "status": "Success",
#     "json_endpoint": "https://serpapi.com/searches/V3qyLRbCzo0RlPXbckRXVQ/69dff9dffdfbab3bc1a2f4e1.json",
#     "created_at": "2026-04-15 20:49:35 UTC",
#     "processed_at": "2026-04-15 20:49:35 UTC",
#     "youtube_video_transcript_url": "https://www.youtube.com/watch?v=BzTdcoUSgaA&t=13620s",
#     "raw_html_file": "https://serpapi.com/searches/V3qyLRbCzo0RlPXbckRXVQ/69dff9dffdfbab3bc1a2f4e1.html",
#     "prettify_html_file": "https://serpapi.com/searches/V3qyLRbCzo0RlPXbckRXVQ/69dff9dffdfbab3bc1a2f4e1.prettify",
#     "total_time_taken": 9.11
#   },
#   "search_parameters": {
#     "engine": "youtube_video_transcript",
#     "v": "BzTdcoUSgaA&t=13620s",
#     "language_code": "en",
#     "type": "asr"
#   },
#   "transcript": [
#     {
#       "start_ms": 0,
#       "snippet": "When he woke in the woods, in the dark and the cold of the night, he'd reach out to touch the child sleeping beside him. Nights dark beyond darkness, and",
#       "start_time_text": "0:00",
#       "start_time_label": "0 seconds"
#     },
#     {
#       "start_ms": 8000,
#       "snippet": "the days more gray, each one what had gone before, like the onset of some cold glaucoma, dimming away the world. His",
#       "start_time_text": "0:08",
#       "start_time_label": "8 seconds"
#     },
#     {
#       "start_ms": 17000,
#       "snippet": "hand rose and fell softly with each precious breath. He pushed away the plastic tarpulin and raised himself in",
#       "start_time_text": "0:17",
#       "start_time_label": "17 seconds"
#     },
#     {
#       "start_ms": 24000,
#       "snippet": "the stinking robes and blankets and looked toward the east for any light,",
#       "start_time_text": "0:24",
#       "start_time_label": "24 seconds"
#     },
#     {
#       "start_ms": 28000,
#       "snippet": "but there was none. In the dream from which he'd wakened, he had wandered in a cave where the child led him by the hand. Their light plain over the wet",
#       "start_time_text": "0:28",
#       "start_time_label": "28 seconds"
#     },
#     {
#       "start_ms": 37000,
#       "snippet": "flow stone walls, like pilgrims in a fable, swallowed up and lost among the inward parts of some grrenitic beast.",
#       "start_time_text": "0:37",
#       "start_time_label": "37 seconds"
#     },
#     {
#       "start_ms": 45000,
#       "snippet": "Deep stone flues where the water dripped and sang tolling in the silence the minutes of the earth and the hours and the days of it years without cease.",
#       "start_time_text": "0:45",
#       "start_time_label": "45 seconds"
#     },
#     {
#       "start_ms": 55000,
#       "snippet": "Till they stood in a great stone room where lay a black and ancient lake. And on the far shore a creature that raised",
#       "start_time_text": "0:55",
#       "start_time_label": "55 seconds"
#     },
#     {
#       "start_ms": 62000,
#       "snippet": "its dripping mouth from the rimstone pool and stared into the light with eyes dead white and sightless as the eggs of spiders.",
#       "start_time_text": "1:02",
#       "start_time_label": "1 minute, 2 seconds"
#     },
#     {
#       "start_ms": 72000,
#       "snippet": "It swung its head low over the water as if to take the sin of what it could not see. Crouching there, pale and naked and",
#       "start_time_text": "1:12",
#       "start_time_label": "1 minute, 12 seconds"
#     },
#     {
#       "start_ms": 79000,
#       "snippet": "translucent, its alabaster bones cast up in shadow on the rocks behind it. Its boughels, its beating heart, the brain",
#       "start_time_text": "1:19",
#       "start_time_label": "1 minute, 19 seconds"
#     },
#     {
#       "start_ms": 88000,
#       "snippet": "that pulsed in a dull glass bell. It swung its head from side to side and then gave out a low moan and turned and",
#       "start_time_text": "1:28",
#       "start_time_label": "1 minute, 28 seconds"
#     },
#     {
#       "start_ms": 96000,
#       "snippet": "lurched away and loped soundlessly into the dark.",
#       "start_time_text": "1:36",
#       "start_time_label": "1 minute, 36 seconds"
#     },
#     {
#       "start_ms": 101000,
#       "snippet": "In my junior year of high school, our English and literature class had a focus on American literature, specifically many of the famous American poets. So that year, we covered Dickinson,",
#       "start_time_text": "1:41",
#       "start_time_label": "1 minute, 41 seconds"
#     },
#     {
#       "start_ms": 112000,
#       "snippet": "Emerson, Poe. But as with most high school English classes, there were some novels thrown in throughout the year that we were supposed to read and write",
#       "start_time_text": "1:52",
#       "start_time_label": "1 minute, 52 seconds"
#     },
#     {
#       "start_ms": 119000,
#       "snippet": "book reports on. And some of the books we read that year were interesting, like Lord of the Flies and Hatchet. But for reasons I'm sure a lot of you can relate",
#       "start_time_text": "1:59",
#       "start_time_label": "1 minute, 59 seconds"
#     },
#     {
#       "start_ms": 127000,
#       "snippet": "to. I think a lot of my enjoyment for those stories was pulled away because it was homework. Also, importantly, I was 16 and stupid. But, you know, even the",
#       "start_time_text": "2:07",
#       "start_time_label": "2 minutes, 7 seconds"
#     },
#     {
#       "start_ms": 136000,
#       "snippet": "best of stories can come off as a drag sometimes if you're being forced to do them. But, there was one book we read that year that that didn't apply to. My",
#       "start_time_text": "2:16",
#       "start_time_label": "2 minutes, 16 seconds"
#     },
#     {
#       "start_ms": 144000,
#       "snippet": "junior English teacher was a man named Mr. Lockhart. And there was one book that he had taught years before in his previous American literature course that",
#       "start_time_text": "2:24",
#       "start_time_label": "2 minutes, 24 seconds"
#     },
#     {
#       "start_ms": 151000,
#       "snippet": "when he got this new class, my class, he demanded he could teach again. This intrigued me for a couple reasons. For one, it's weird to see a teacher so",
#       "start_time_text": "2:31",
#       "start_time_label": "2 minutes, 31 seconds"
#     },
#     {
#       "start_ms": 160000,
#       "snippet": "passionate to get one specific book into the curriculum. And two, I had heard about this book before. Because as a",
#       "start_time_text": "2:40",
#       "start_time_label": "2 minutes, 40 seconds"
#     },
#     {
#       "start_ms": 167000,
#       "snippet": "young kid into creepy pastas and scary movies and spooky stories, many regarded this book as one of the darkest stories ever written. Not to mention that some",
#       "start_time_text": "2:47",
#       "start_time_label": "2 minutes, 47 seconds"
#     },
#     {
#       "start_ms": 176000,
#       "snippet": "parts of the book were set in the town that I grew up. So if all those details had my interest, what hooked it was the first day we talked about the book. I",
#       "start_time_text": "2:56",
#       "start_time_label": "2 minutes, 56 seconds"
#     },
#     {
#       "start_ms": 184000,
#       "snippet": "remember so distinctly Mr. Lockheart standing in front of the class and reading a few of the lines from the first pages of the story. And as he did,",
#       "start_time_text": "3:04",
#       "start_time_label": "3 minutes, 4 seconds"
#     },
#     {
#       "start_ms": 193000,
#       "snippet": "he began to cry, apologizing to the class and saying that this story is one that's very powerful to him and one that's very impactful to any father. For",
#       "start_time_text": "3:13",
#       "start_time_label": "3 minutes, 13 seconds"
#     },
#     {
#       "start_ms": 202000,
#       "snippet": "the first time I could remember, I was excited to do my homework and I went home that night and read the entire book. That story became what is still",
#       "start_time_text": "3:22",
#       "start_time_label": "3 minutes, 22 seconds"
#     },
#     {
#       "start_ms": 209000,
#       "snippet": "today my favorite book and it introduced me to my favorite author. But more than that, it ignited an already kindling love of stories that I had into a fire.",
#       "start_time_text": "3:29",
#       "start_time_label": "3 minutes, 29 seconds"
#     },
#     {
#       "start_ms": 220000,
#       "snippet": "That fire continued to burn until I had to make a YouTube channel to talk about some of my favorites. So, my favorite book and the one that directly led me to",
#       "start_time_text": "3:40",
#       "start_time_label": "3 minutes, 40 seconds"
#     },
#     {
#       "start_ms": 228000,
#       "snippet": "talking in front of a camera to you all now is Cormick McCarthy's The Road. The Road is a story that's so special to me, I've been hesitant to talk about it.",
#       "start_time_text": "3:48",
#       "start_time_label": "3 minutes, 48 seconds"
#     },
#     {
#       "start_ms": 236000,
#       "snippet": "Sure, I've talked about McCarthy's other works like No Country for Old Men and Blood Meridian, the second of which being one of the most popular videos on",
#       "start_time_text": "3:56",
#       "start_time_label": "3 minutes, 56 seconds"
#     },
#     {
#       "start_ms": 244000,
#       "snippet": "the channel. But anytime I would think about talking about the road, I'd be almost scared to. Like, how do you talk about something that means so much to you personally? I mean, what if you miss something or you get something wrong?",
#       "start_time_text": "4:04",
#       "start_time_label": "4 minutes, 4 seconds"
#     },
#     {
#       "start_ms": 254000,
#       "snippet": "But as many of you know, I recently became a father. And one of the core points of this book is fatherhood. So, I guess now is as good of a time as ever.",
#       "start_time_text": "4:14",
#       "start_time_label": "4 minutes, 14 seconds"
#     },
#     {
#       "start_ms": 262000,
#       "snippet": "And I should probably also tell you what this book's about. The road follows a father and son as they make their way through a post-apocalyptic America. We",
#       "start_time_text": "4:22",
#       "start_time_label": "4 minutes, 22 seconds"
#     },
#     {
#       "start_ms": 270000,
#       "snippet": "get some clues as to what the apocalypse might have been, but for the sake of the story, it doesn't matter. What matters is the relationship between the father",
#       "start_time_text": "4:30",
#       "start_time_label": "4 minutes, 30 seconds"
#     },
#     {
#       "start_ms": 277000,
#       "snippet": "and son as they brave this horrifying new world. a world full of such terrible occurrences that it's given the book the reputation as one of the darkest stories",
#       "start_time_text": "4:37",
#       "start_time_label": "4 minutes, 37 seconds"
#     },
#     {
#       "start_ms": 286000,
#       "snippet": "ever written, which I'm going to give a big viewer discretion to this whole video. The book deals with topics like cannibalism and child death and other",
#       "start_time_text": "4:46",
#       "start_time_label": "4 minutes, 46 seconds"
#     },
#     {
#       "start_ms": 295000,
#       "snippet": "things you've come to know and love on this channel. I would never call the book gratuitous, especially because of the context in which these events show",
#       "start_time_text": "4:55",
#       "start_time_label": "4 minutes, 55 seconds"
#     },
#     {
#       "start_ms": 303000,
#       "snippet": "up, but it is there if you're sensitive to that. And of course, most importantly, The Road to Me is a very important book. It's a once in",
#       "start_time_text": "5:03",
#       "start_time_label": "5 minutes, 3 seconds"
#     },
#     {
#       "start_ms": 311000,
#       "snippet": "a-lifetime experience, and it's not one that I want to ruin for you. So, there will be a link to the book in the description below. Please check it out",
#       "start_time_text": "5:11",
#       "start_time_label": "5 minutes, 11 seconds"
#     },
#     {
#       "start_ms": 319000,
#       "snippet": "for yourself first, and then come back and we can talk about it. Stories like this are too important to let your first experience be made murky with someone's",
#       "start_time_text": "5:19",
#       "start_time_label": "5 minutes, 19 seconds"
#     },
#     {
#       "start_ms": 326000,
#       "snippet": "interpretation. But aside from just the literal events described, the philosophy of the book is so interesting. sometimes conveyed through dreams like what you",
#       "start_time_text": "5:26",
#       "start_time_label": "5 minutes, 26 seconds"
#     },
#     {
#       "start_ms": 334000,
#       "snippet": "heard at the start of the video, the opening words of the book, sometimes hinted through characters and dialogue.",
#       "start_time_text": "5:34",
#       "start_time_label": "5 minutes, 34 seconds"
#     },
#     {
#       "start_ms": 339000,
#       "snippet": "It all comes together to create a narrative that is so cohesive and compelling that I am equally excited as I am nervous to talk about it. So",
#       "start_time_text": "5:39",
#       "start_time_label": "5 minutes, 39 seconds"
#     },
#     {
#       "start_ms": 347000,
#       "snippet": "hopefully you decide to talk about it with me. And if all this sounds interesting to you, then stick around after the ad as we talk about the misery and fire of Cormick McCarthy's The Road.",
#       "start_time_text": "5:47",
#       "start_time_label": "5 minutes, 47 seconds"
#     },
#     {
#       "start_ms": 357000,
#       "snippet": "While it might be fun to read about someone starving to death, you shouldn't do that to yourself. But now, healthy, delicious meals have never been easier.",
#       "start_time_text": "5:57",
#       "start_time_label": "5 minutes, 57 seconds"
#     },
#     {
#       "start_ms": 365000,
#       "snippet": "Thanks to today's sponsor, Factor. Factor delivers fresh, never frozen,",
#       "start_time_text": "6:05",
#       "start_time_label": "6 minutes, 5 seconds"
#     },
#     {
#       "start_ms": 369000,
#       "snippet": "chef crafted, and dietitian approved meals straight to your door. They're ready to heat and eat in just 2 minutes,",
#       "start_time_text": "6:09",
#       "start_time_label": "6 minutes, 9 seconds"
#     },
#     {
#       "start_ms": 375000,
#       "snippet": "and they're designed to support your wellness journey. Factor can help eliminate the stress around cooking,",
#       "start_time_text": "6:15",
#       "start_time_label": "6 minutes, 15 seconds"
#     },
#     {
#       "start_ms": 380000,
#       "snippet": "planning, or cleanup, so you can stay focused on your goals. Every week,",
#       "start_time_text": "6:20",
#       "start_time_label": "6 minutes, 20 seconds"
#     },
#     {
#       "start_ms": 383000,
#       "snippet": "Factor has over 100 rotating meal options. and not just meals, but things like salads, shakes, breakfast, and more. They're doubling up on things like",
#       "start_time_text": "6:23",
#       "start_time_label": "6 minutes, 23 seconds"
#     },
#     {
#       "start_ms": 392000,
#       "snippet": "their protein options and their seafood options. And they can accommodate any dietary restriction you have, such as keto, gluten, or you can even swap",
#       "start_time_text": "6:32",
#       "start_time_label": "6 minutes, 32 seconds"
#     },
#     {
#       "start_ms": 399000,
#       "snippet": "protein options to fit whatever is right for you. And as I mentioned, there's virtually no prep or cleanup as they're ready to make in just 2 minutes. Most of",
#       "start_time_text": "6:39",
#       "start_time_label": "6 minutes, 39 seconds"
#     },
#     {
#       "start_ms": 407000,
#       "snippet": "us get short on time, so we neglect our health in order to eat something that's cheap and quick. But now you can have something that's cheap and quick and",
#       "start_time_text": "6:47",
#       "start_time_label": "6 minutes, 47 seconds"
#     },
#     {
#       "start_ms": 414000,
#       "snippet": "good for you and tastes really good as well. Backtor will send me meals for things that I think have no business being in the microwave. Things like fish",
#       "start_time_text": "6:54",
#       "start_time_label": "6 minutes, 54 seconds"
#     },
#     {
#       "start_ms": 421000,
#       "snippet": "or tofu or steak. Somehow whatever they're doing to their food just works.",
#       "start_time_text": "7:01",
#       "start_time_label": "7 minutes, 1 second"
#     },
#     {
#       "start_ms": 425000,
#       "snippet": "And I believe a lot of it comes down to their food quality. Factor bans over 175 ingredients. Things like refined seed oils or artificial sugars in order to",
#       "start_time_text": "7:05",
#       "start_time_label": "7 minutes, 5 seconds"
#     },
#     {
#       "start_ms": 434000,
#       "snippet": "give you nutrient-dense foods that focused on your energy and health. As of late, Factor hasn't sent me a meal I haven't liked. It feels like I'm having",
#       "start_time_text": "7:14",
#       "start_time_label": "7 minutes, 14 seconds"
#     },
#     {
#       "start_ms": 442000,
#       "snippet": "a cheat day without the guilt. So, if you want to get in on this fantastic product, then now's the perfect time.",
#       "start_time_text": "7:22",
#       "start_time_label": "7 minutes, 22 seconds"
#     },
#     {
#       "start_ms": 447000,
#       "snippet": "That's because if you head to factor75.com or click the link in the description and use code windagon FB50, you'll get 50%",
#       "start_time_text": "7:27",
#       "start_time_label": "7 minutes, 27 seconds"
#     },
#     {
#       "start_ms": 454000,
#       "snippet": "off your first Factor box plus free breakfast for a year. That's right, half off your first box and free breakfast",
#       "start_time_text": "7:34",
#       "start_time_label": "7 minutes, 34 seconds"
#     },
#     {
#       "start_ms": 462000,
#       "snippet": "for a year while your subscription lasts. Again, head to the link in the description at factor75.com and use code windagonf50 to get in on this incredible",
#       "start_time_text": "7:42",
#       "start_time_label": "7 minutes, 42 seconds"
#     },
#     {
#       "start_ms": 470000,
#       "snippet": "offer today. Thank you all for watching the ad. Thank you to Factor for sponsoring the channel. Their link will be in the description. We are now back",
#       "start_time_text": "7:50",
#       "start_time_label": "7 minutes, 50 seconds"
#     },
#     {
#       "start_ms": 477000,
#       "snippet": "to the video. We are going to go ahead and get into it, but as always, thank you for watching. Also, I feel like I should point out uh I'm not just wearing",
#       "start_time_text": "7:57",
#       "start_time_label": "7 minutes, 57 seconds"
#     },
#     {
#       "start_ms": 486000,
#       "snippet": "a bandage to like cosplay. I wrecked a dirt bike because I'm stupid. But if there ever was a time to be stupid, it",
#       "start_time_text": "8:06",
#       "start_time_label": "8 minutes, 6 seconds"
#     },
#     {
#       "start_ms": 494000,
#       "snippet": "would be now because it matches the aesthetics for this video. Anyway, in the opening of the book is a dedication",
#       "start_time_text": "8:14",
#       "start_time_label": "8 minutes, 14 seconds"
#     },
#     {
#       "start_ms": 501000,
#       "snippet": "to Cor McCarthy's son, John Francis McCarthy. John was born in 1999,",
#       "start_time_text": "8:21",
#       "start_time_label": "8 minutes, 21 seconds"
#     },
#     {
#       "start_ms": 506000,
#       "snippet": "according to the internet. So, at the time of the book's publication, he would have been 6 or 7 years old. Because of that, it's apparent, as Corormick would",
#       "start_time_text": "8:26",
#       "start_time_label": "8 minutes, 26 seconds"
#     },
#     {
#       "start_ms": 514000,
#       "snippet": "later go on to state, that his relationship with his son was his influence for the story. We already got some of the key ideas of the book out of",
#       "start_time_text": "8:34",
#       "start_time_label": "8 minutes, 34 seconds"
#     },
#     {
#       "start_ms": 521000,
#       "snippet": "the way in the introduction. The world is dark in a way that's hard to imagine.",
#       "start_time_text": "8:41",
#       "start_time_label": "8 minutes, 41 seconds"
#     },
#     {
#       "start_ms": 525000,
#       "snippet": "We'll later see that the sun itself is blotted out by a gray sky. So, if the day is that dark, you could imagine how dark it is at night. Dark beyond dark,",
#       "start_time_text": "8:45",
#       "start_time_label": "8 minutes, 45 seconds"
#     },
#     {
#       "start_ms": 534000,
#       "snippet": "as the story says. The condition of the man and the boy is dire. Food, as you can imagine, is scarce. The world has been like this for some years now. Their",
#       "start_time_text": "8:54",
#       "start_time_label": "8 minutes, 54 seconds"
#     },
#     {
#       "start_ms": 542000,
#       "snippet": "clothes and blankets stink. Filth upon filth. Years of rot and decay. We can imagine the two of them emaciated and",
#       "start_time_text": "9:02",
#       "start_time_label": "9 minutes, 2 seconds"
#     },
#     {
#       "start_ms": 550000,
#       "snippet": "suffering and not too far from dead. But in the midst of this misery, there's a light. The light being the boy,",
#       "start_time_text": "9:10",
#       "start_time_label": "9 minutes, 10 seconds"
#     },
#     {
#       "start_ms": 555000,
#       "snippet": "something that's personified in the father's first dream. He walks through a dark cave as the child's light guides him. But regardless of the light,",
#       "start_time_text": "9:15",
#       "start_time_label": "9 minutes, 15 seconds"
#     },
#     {
#       "start_ms": 562000,
#       "snippet": "there's something monstrous in here.",
#       "start_time_text": "9:22",
#       "start_time_label": "9 minutes, 22 seconds"
#     },
#     {
#       "start_ms": 564000,
#       "snippet": "Something horrific, growling, and ancient. At the back of this cave, or this world he finds himself in in the dream, the boy is precious, but there's",
#       "start_time_text": "9:24",
#       "start_time_label": "9 minutes, 24 seconds"
#     },
#     {
#       "start_ms": 572000,
#       "snippet": "a monster around the corner. We have further clues to the state of the world in the first lines after the dream. With the first gray light, he rose and left",
#       "start_time_text": "9:32",
#       "start_time_label": "9 minutes, 32 seconds"
#     },
#     {
#       "start_ms": 579000,
#       "snippet": "the boy sleeping and walked out to the road and squatted and studied the country to the south, barren, silent,",
#       "start_time_text": "9:39",
#       "start_time_label": "9 minutes, 39 seconds"
#     },
#     {
#       "start_ms": 587000,
#       "snippet": "godless. He thought the month was October, but he wasn't sure. He hadn't kept a calendar for years. They were",
#       "start_time_text": "9:47",
#       "start_time_label": "9 minutes, 47 seconds"
#     },
#     {
#       "start_ms": 594000,
#       "snippet": "moving south. There'd be no surviving another winter here. As I said, no one's seen the sun for years. Along with the darkness, the world has brought a",
#       "start_time_text": "9:54",
#       "start_time_label": "9 minutes, 54 seconds"
#     },
#     {
#       "start_ms": 603000,
#       "snippet": "coldness to it. As we'll see, everywhere it seems to snow and freeze, but in the north, winters are particularly rough.",
#       "start_time_text": "10:03",
#       "start_time_label": "10 minutes, 3 seconds"
#     },
#     {
#       "start_ms": 610000,
#       "snippet": "So, with no other objective, the man and his boy are going south. There's a few narrative dynamics that need no introduction. Like, in several",
#       "start_time_text": "10:10",
#       "start_time_label": "10 minutes, 10 seconds"
#     },
#     {
#       "start_ms": 618000,
#       "snippet": "instances, it's the job of the writer to make you care about characters within a story, or at least care about their relationship. If we're introduced to two",
#       "start_time_text": "10:18",
#       "start_time_label": "10 minutes, 18 seconds"
#     },
#     {
#       "start_ms": 626000,
#       "snippet": "people, the story needs to establish if they hate each other, love each other,",
#       "start_time_text": "10:26",
#       "start_time_label": "10 minutes, 26 seconds"
#     },
#     {
#       "start_ms": 630000,
#       "snippet": "if they're here by their own decisions or someone else's, etc. But there's a few relationships that kind of cut through the red tape. For example, if",
#       "start_time_text": "10:30",
#       "start_time_label": "10 minutes, 30 seconds"
#     },
#     {
#       "start_ms": 638000,
#       "snippet": "you show a husband and wife, it's assumed that they like each other. The same can be said about brother and sister, mother and daughter, and father",
#       "start_time_text": "10:38",
#       "start_time_label": "10 minutes, 38 seconds"
#     },
#     {
#       "start_ms": 645000,
#       "snippet": "and son. Now, obviously, these relationships don't have to be typical.",
#       "start_time_text": "10:45",
#       "start_time_label": "10 minutes, 45 seconds"
#     },
#     {
#       "start_ms": 648000,
#       "snippet": "The writer can subvert expectations wherever they want. But when we hear those titles, we naturally assume a bond. So with his father taking his son",
#       "start_time_text": "10:48",
#       "start_time_label": "10 minutes, 48 seconds"
#     },
#     {
#       "start_ms": 656000,
#       "snippet": "to the south, normally that would be all we need to assume these two care about each other. But in spite of that,",
#       "start_time_text": "10:56",
#       "start_time_label": "10 minutes, 56 seconds"
#     },
#     {
#       "start_ms": 662000,
#       "snippet": "McCarthy gives one of the most powerful mandates that I think I've ever heard in a story. After looking at the countryside through his binoculars, the",
#       "start_time_text": "11:02",
#       "start_time_label": "11 minutes, 2 seconds"
#     },
#     {
#       "start_ms": 670000,
#       "snippet": "story says he lowered the glasses and pulled down the cotton mask from his face and wiped his nose on the back of his wrist and then glassed the country",
#       "start_time_text": "11:10",
#       "start_time_label": "11 minutes, 10 seconds"
#     },
#     {
#       "start_ms": 678000,
#       "snippet": "again. Then he just sat there holding the binoculars and watching the ash and daylight congeal over the land. He knew",
#       "start_time_text": "11:18",
#       "start_time_label": "11 minutes, 18 seconds"
#     },
#     {
#       "start_ms": 685000,
#       "snippet": "only that the child was his warrant. He said, \"If he is not the word of God, God never spoke.\" Earlier when I said my",
#       "start_time_text": "11:25",
#       "start_time_label": "11 minutes, 25 seconds"
#     },
#     {
#       "start_ms": 694000,
#       "snippet": "junior English teacher cried reading the opening lines of the story, this is the line he cried during. It is such a powerful line that so succinctly",
#       "start_time_text": "11:34",
#       "start_time_label": "11 minutes, 34 seconds"
#     },
#     {
#       "start_ms": 702000,
#       "snippet": "encapsulates the idea that our father is setting out with. The world is empty. it is dead and there is no good to be had.",
#       "start_time_text": "11:42",
#       "start_time_label": "11 minutes, 42 seconds"
#     },
#     {
#       "start_ms": 709000,
#       "snippet": "But if there is a god, then he looks like that. It gives us the idea that the father isn't doing all of this just to save his son, but for some greater",
#       "start_time_text": "11:49",
#       "start_time_label": "11 minutes, 49 seconds"
#     },
#     {
#       "start_ms": 718000,
#       "snippet": "purpose for humanity's sake, as if the child himself is a vessel. He's the last carrier of something that the world seems to have forgotten. This idea of",
#       "start_time_text": "11:58",
#       "start_time_label": "11 minutes, 58 seconds"
#     },
#     {
#       "start_ms": 726000,
#       "snippet": "God, or the closest thing we have to God, will continue throughout the story.",
#       "start_time_text": "12:06",
#       "start_time_label": "12 minutes, 6 seconds"
#     },
#     {
#       "start_ms": 730000,
#       "snippet": "Also, the father and the son will never be named. They are simply called the man and the boy. McCarthy does this a lot in his works. Like the protagonist from",
#       "start_time_text": "12:10",
#       "start_time_label": "12 minutes, 10 seconds"
#     },
#     {
#       "start_ms": 739000,
#       "snippet": "Blood Meridian was just known as the kid. Because in that story, his name didn't matter. He was the witness. His inclusion, if there was any in the",
#       "start_time_text": "12:19",
#       "start_time_label": "12 minutes, 19 seconds"
#     },
#     {
#       "start_ms": 747000,
#       "snippet": "atrocities the Glanton gang committed was omitted. Because the core of the story was about how everything affected him. If the things he saw changed him as",
#       "start_time_text": "12:27",
#       "start_time_label": "12 minutes, 27 seconds"
#     },
#     {
#       "start_ms": 755000,
#       "snippet": "a person for better or worse by the time of the story's end. In that way, the kid was a stand-in for something greater. a pseudonym for true humanity that",
#       "start_time_text": "12:35",
#       "start_time_label": "12 minutes, 35 seconds"
#     },
#     {
#       "start_ms": 763000,
#       "snippet": "witnessed atrocities and allowed them to pass by without delay. Because of that,",
#       "start_time_text": "12:43",
#       "start_time_label": "12 minutes, 43 seconds"
#     },
#     {
#       "start_ms": 767000,
#       "snippet": "he doesn't need a name. He's just the kid. And here in this story, the man and the boy are much the same, but we'll talk about how later. We get some",
#       "start_time_text": "12:47",
#       "start_time_label": "12 minutes, 47 seconds"
#     },
#     {
#       "start_ms": 775000,
#       "snippet": "description as to how the two of them live. All of their belongings are in a grocery cart, one they undoubtedly scavenge from some decrepit grocery",
#       "start_time_text": "12:55",
#       "start_time_label": "12 minutes, 55 seconds"
#     },
#     {
#       "start_ms": 782000,
#       "snippet": "store and now used to haul all of their belongings, from tarbs to old cornmeal cakes. Food is scarce, but the man rations what food he has between him and",
#       "start_time_text": "13:02",
#       "start_time_label": "13 minutes, 2 seconds"
#     },
#     {
#       "start_ms": 791000,
#       "snippet": "the boy. Much of the dialogue between the man and the boy feels authentic.",
#       "start_time_text": "13:11",
#       "start_time_label": "13 minutes, 11 seconds"
#     },
#     {
#       "start_ms": 795000,
#       "snippet": "There are very few moments of them pondering things or telling stories or describing the world around them. I mean, they've been in this world for",
#       "start_time_text": "13:15",
#       "start_time_label": "13 minutes, 15 seconds"
#     },
#     {
#       "start_ms": 803000,
#       "snippet": "years now. Any conversation like that they've already had. Instead, most of their dialogue is simply what it needs to be, reassurances. The boy turned in the blankets, then he opened his eyes.",
#       "start_time_text": "13:23",
#       "start_time_label": "13 minutes, 23 seconds"
#     },
#     {
#       "start_ms": 814000,
#       "snippet": "\"Hi, Papa,\" he said. I'm right here. I know.",
#       "start_time_text": "13:34",
#       "start_time_label": "13 minutes, 34 seconds"
#     },
#     {
#       "start_ms": 819000,
#       "snippet": "Just a simple assurance that the father is here and the boy is safe. This is also a good time to point out if you're not familiar with McCarthy's work that",
#       "start_time_text": "13:39",
#       "start_time_label": "13 minutes, 39 seconds"
#     },
#     {
#       "start_ms": 826000,
#       "snippet": "he doesn't like punctuation. Like straight up, he has said before, \"Why would I want to cover up the page in silly little marks, so he just doesn't",
#       "start_time_text": "13:46",
#       "start_time_label": "13 minutes, 46 seconds"
#     },
#     {
#       "start_ms": 834000,
#       "snippet": "do it.\" I didn't even know you could do that before I started reading his stuff.",
#       "start_time_text": "13:54",
#       "start_time_label": "13 minutes, 54 seconds"
#     },
#     {
#       "start_ms": 838000,
#       "snippet": "If you don't like quotation marks or colons or semicolons, you just pretend like they don't exist, I guess. Because of that, moments of dialogue like that",
#       "start_time_text": "13:58",
#       "start_time_label": "13 minutes, 58 seconds"
#     },
#     {
#       "start_ms": 845000,
#       "snippet": "are just text on the page that occurs after each other. The only indicator we get that the speaker has switched is a new indent. But because of the way",
#       "start_time_text": "14:05",
#       "start_time_label": "14 minutes, 5 seconds"
#     },
#     {
#       "start_ms": 853000,
#       "snippet": "different characters speak and flow in dialogue, it's not really confusing as to who's talking. Now, sure, part of that is McCarthy's skill as a writer,",
#       "start_time_text": "14:13",
#       "start_time_label": "14 minutes, 13 seconds"
#     },
#     {
#       "start_ms": 862000,
#       "snippet": "but also like 99% of the dialogue is between a grown man and a child, so there's normally not a lot of wiggle",
#       "start_time_text": "14:22",
#       "start_time_label": "14 minutes, 22 seconds"
#     },
#     {
#       "start_ms": 870000,
#       "snippet": "room. The father pushes the grocery cart that has an old motorcycle mirror attached to it. That way, he can always keep his eyes forward, but have an idea if something's coming behind them.",
#       "start_time_text": "14:30",
#       "start_time_label": "14 minutes, 30 seconds"
#     },
#     {
#       "start_ms": 880000,
#       "snippet": "Animals in this world seem to be completely extinct. But there's other people out there. In addition to that,",
#       "start_time_text": "14:40",
#       "start_time_label": "14 minutes, 40 seconds"
#     },
#     {
#       "start_ms": 886000,
#       "snippet": "both he and the boy have on a backpack to carry essential things in case they need to ditch the shopping cart. The only weapon they have is an old",
#       "start_time_text": "14:46",
#       "start_time_label": "14 minutes, 46 seconds"
#     },
#     {
#       "start_ms": 894000,
#       "snippet": "revolver, a revolver of which they only have two bullets. As they press on into the day, the story says, \"Then they set out along the black top in the gunmetal",
#       "start_time_text": "14:54",
#       "start_time_label": "14 minutes, 54 seconds"
#     },
#     {
#       "start_ms": 902000,
#       "snippet": "light, shuffling through the ash. Each the others swirled entire.\" The only translator understanding the boy has for",
#       "start_time_text": "15:02",
#       "start_time_label": "15 minutes, 2 seconds"
#     },
#     {
#       "start_ms": 910000,
#       "snippet": "the world around him, is the man. And the only thing that makes sense to the man, the only thing worth pushing on for is the boy. The two need each other in a way that's hard to put into words.",
#       "start_time_text": "15:10",
#       "start_time_label": "15 minutes, 10 seconds"
#     },
#     {
#       "start_ms": 920000,
#       "snippet": "There's also the mention of them shuffling through the ash. Again, we don't know exactly how this apocalypse happened, but we know it involved a lot of fire, or the very least, it caused a",
#       "start_time_text": "15:20",
#       "start_time_label": "15 minutes, 20 seconds"
#     },
#     {
#       "start_ms": 928000,
#       "snippet": "lot of fire. Perhaps a meteor hit the Earth. Perhaps there was some massive solar event. Perhaps a nuclear war.",
#       "start_time_text": "15:28",
#       "start_time_label": "15 minutes, 28 seconds"
#     },
#     {
#       "start_ms": 935000,
#       "snippet": "Whatever it is, it killed all plant life, killed out all animal life, and has almost killed out all human life. In addition to this, ash rains around the",
#       "start_time_text": "15:35",
#       "start_time_label": "15 minutes, 35 seconds"
#     },
#     {
#       "start_ms": 944000,
#       "snippet": "world constantly like snow. It hangs in the air and coats everything. In most apocalyptic stories, there is a hope for a world beyond, regardless if it's",
#       "start_time_text": "15:44",
#       "start_time_label": "15 minutes, 44 seconds"
#     },
#     {
#       "start_ms": 952000,
#       "snippet": "zombies or a disease outbreak or natural disasters. These stories are normally underlined by the idea of a reward at",
#       "start_time_text": "15:52",
#       "start_time_label": "15 minutes, 52 seconds"
#     },
#     {
#       "start_ms": 959000,
#       "snippet": "the end of perseverance. If I can get through this, things will get better. If I can get through this, humanity will be okay. But the road's unique in the idea that nothing will ever be okay again.",
#       "start_time_text": "15:59",
#       "start_time_label": "15 minutes, 59 seconds"
#     },
#     {
#       "start_ms": 970000,
#       "snippet": "Humanity is not dying. We are extinct.",
#       "start_time_text": "16:10",
#       "start_time_label": "16 minutes, 10 seconds"
#     },
#     {
#       "start_ms": 973000,
#       "snippet": "And the survivors just haven't got that memo yet. Now, it's not like the road is the only story to have an inevitable extinction of humanity. Given some of",
#       "start_time_text": "16:13",
#       "start_time_label": "16 minutes, 13 seconds"
#     },
#     {
#       "start_ms": 980000,
#       "snippet": "the things we're going to see, it's certainly one of the most depressing. As they're walking, the two of them come to an old gas station. Everything there's been looted. If not in the immediate aftermath of this apocalyptic event,",
#       "start_time_text": "16:20",
#       "start_time_label": "16 minutes, 20 seconds"
#     },
#     {
#       "start_ms": 991000,
#       "snippet": "then in the years since of other travelers like themselves passing by.",
#       "start_time_text": "16:31",
#       "start_time_label": "16 minutes, 31 seconds"
#     },
#     {
#       "start_ms": 995000,
#       "snippet": "However, as they're making their way through the gas station, the story says this. He went into the office, dust and ash everywhere. The boy stood in the",
#       "start_time_text": "16:35",
#       "start_time_label": "16 minutes, 35 seconds"
#     },
#     {
#       "start_ms": 1003000,
#       "snippet": "door. a metal desk, cash register, some old automotive manuals, swollen and soden. The lenolum was stained and",
#       "start_time_text": "16:43",
#       "start_time_label": "16 minutes, 43 seconds"
#     },
#     {
#       "start_ms": 1011000,
#       "snippet": "curling from the leaking roof. He crossed to the desk and stood there.",
#       "start_time_text": "16:51",
#       "start_time_label": "16 minutes, 51 seconds"
#     },
#     {
#       "start_ms": 1016000,
#       "snippet": "Then he picked up the phone and dialed the number of his father's house in that long ago. The boy watched him. \"What are",
#       "start_time_text": "16:56",
#       "start_time_label": "16 minutes, 56 seconds"
#     },
#     {
#       "start_ms": 1024000,
#       "snippet": "you doing?\" he said. This is such an interesting little moment and one that I haven't seen discussed enough regarding",
#       "start_time_text": "17:04",
#       "start_time_label": "17 minutes, 4 seconds"
#     },
#     {
#       "start_ms": 1032000,
#       "snippet": "this book because there's this subtle underlining throughout the book of the father's declining mentality or if not",
#       "start_time_text": "17:12",
#       "start_time_label": "17 minutes, 12 seconds"
#     },
#     {
#       "start_ms": 1039000,
#       "snippet": "necessarily a decline, a rejection of the state he finds himself in. I believe the father here knew that this was a senseless act, but it was an act",
#       "start_time_text": "17:19",
#       "start_time_label": "17 minutes, 19 seconds"
#     },
#     {
#       "start_ms": 1047000,
#       "snippet": "nonetheless and one that he could do. In a world where so much agency was ripped from him, it's been a while since he picked up a phone and called his dad's",
#       "start_time_text": "17:27",
#       "start_time_label": "17 minutes, 27 seconds"
#     },
#     {
#       "start_ms": 1055000,
#       "snippet": "house. And of course, there's the obvious connection between him being the father now and trying to call someone who will never pick up, someone who was",
#       "start_time_text": "17:35",
#       "start_time_label": "17 minutes, 35 seconds"
#     },
#     {
#       "start_ms": 1062000,
#       "snippet": "a father to him. They get a little bit away from the gas station before the father remarks that they're being sloppy. There's more stuff they could have salvaged from there that other",
#       "start_time_text": "17:42",
#       "start_time_label": "17 minutes, 42 seconds"
#     },
#     {
#       "start_ms": 1070000,
#       "snippet": "people have left. So, they go back, take all the empty oil quarts, and turn them upside down into one oil jug. By the time they're done, they have a half",
#       "start_time_text": "17:50",
#       "start_time_label": "17 minutes, 50 seconds"
#     },
#     {
#       "start_ms": 1078000,
#       "snippet": "quart of motor oil. Oil that they can use for their campsite lantern. The boy remarks that this means his dad can read him a story tonight. Obviously, the most human element of the book is the boy.",
#       "start_time_text": "17:58",
#       "start_time_label": "17 minutes, 58 seconds"
#     },
#     {
#       "start_ms": 1089000,
#       "snippet": "He's a picture of innocence in a world that's long since forgotten. So, because of that, moments like that, where the boy is excited in the midst of everything that his dad gets to read him",
#       "start_time_text": "18:09",
#       "start_time_label": "18 minutes, 9 seconds"
#     },
#     {
#       "start_ms": 1097000,
#       "snippet": "at bedtime story is refreshing, but stands in almost comedic contrast to the world around him. And moments like that further emphasize to us what the father",
#       "start_time_text": "18:17",
#       "start_time_label": "18 minutes, 17 seconds"
#     },
#     {
#       "start_ms": 1106000,
#       "snippet": "sees in him. Even if you're at your wits end and want it all to be over, if your son asked you to read a story, how could you not keep pushing on? For the two, it",
#       "start_time_text": "18:26",
#       "start_time_label": "18 minutes, 26 seconds"
#     },
#     {
#       "start_ms": 1114000,
#       "snippet": "seems that every night is a fight against the elements. The world is cold in the day, and it is freezing at night.",
#       "start_time_text": "18:34",
#       "start_time_label": "18 minutes, 34 seconds"
#     },
#     {
#       "start_ms": 1120000,
#       "snippet": "Add to this that rainstorms seem to be near constant. They keep tarps with them to lay over top of them as they sleep curled into each other. Being too cold",
#       "start_time_text": "18:40",
#       "start_time_label": "18 minutes, 40 seconds"
#     },
#     {
#       "start_ms": 1129000,
#       "snippet": "can be a problem, but being too cold and wet is dangerous. So, in one of their first nights, when they see it beginning to rain, they put a tarp over the",
#       "start_time_text": "18:49",
#       "start_time_label": "18 minutes, 49 seconds"
#     },
#     {
#       "start_ms": 1137000,
#       "snippet": "shopping cart and make their way to a large rock. Grilling up in the dry dirt under the rock for the night. In the deep dark, the boy asks if it's okay if",
#       "start_time_text": "18:57",
#       "start_time_label": "18 minutes, 57 seconds"
#     },
#     {
#       "start_ms": 1145000,
#       "snippet": "they can leave the lamp on for a little bit. To which the father replies, \"Yes,",
#       "start_time_text": "19:05",
#       "start_time_label": "19 minutes, 5 seconds"
#     },
#     {
#       "start_ms": 1149000,
#       "snippet": "of course, we can.\" Logically, this doesn't make any sense. They need to conserve their resources. But to the father, what point is there beyond making his son comfortable? That night,",
#       "start_time_text": "19:09",
#       "start_time_label": "19 minutes, 9 seconds"
#     },
#     {
#       "start_ms": 1158000,
#       "snippet": "laying in the dark under the stone, the two have this conversation. He was a long time going to sleep. After a while,",
#       "start_time_text": "19:18",
#       "start_time_label": "19 minutes, 18 seconds"
#     },
#     {
#       "start_ms": 1164000,
#       "snippet": "he turned and looked at the man. His face in the small light stre with black from the rain like some old world thespian. \"Can I ask you something?\" he",
#       "start_time_text": "19:24",
#       "start_time_label": "19 minutes, 24 seconds"
#     },
#     {
#       "start_ms": 1174000,
#       "snippet": "said. \"Yes, of course.\" \"Are we going to die?\" \"Sometime. Not now.\" \"And we're",
#       "start_time_text": "19:34",
#       "start_time_label": "19 minutes, 34 seconds"
#     },
#     {
#       "start_ms": 1182000,
#       "snippet": "still going south?\" \"Yes.\" So, we'll be warm. Yes. Okay.",
#       "start_time_text": "19:42",
#       "start_time_label": "19 minutes, 42 seconds"
#     },
#     {
#       "start_ms": 1190000,
#       "snippet": "Okay. For what? Nothing. Just Okay. Go to sleep. Okay. I'm going to blow out the lamp. Is that okay?",
#       "start_time_text": "19:50",
#       "start_time_label": "19 minutes, 50 seconds"
#     },
#     {
#       "start_ms": 1200000,
#       "snippet": "Yes, that's okay. And then later in the darkness, can I ask you something?",
#       "start_time_text": "20:00",
#       "start_time_label": "20 minutes"
#     },
#     {
#       "start_ms": 1209000,
#       "snippet": "Yes, of course you can. What would you do if I died? If you died, I would want to die, too.",
#       "start_time_text": "20:09",
#       "start_time_label": "20 minutes, 9 seconds"
#     },
#     {
#       "start_ms": 1218000,
#       "snippet": "So you could be with me? Yes. So I could be with you. Okay.",
#       "start_time_text": "20:18",
#       "start_time_label": "20 minutes, 18 seconds"
#     },
#     {
#       "start_ms": 1226000,
#       "snippet": "This is what I mean by most of the dialogue feels like what it would be,",
#       "start_time_text": "20:26",
#       "start_time_label": "20 minutes, 26 seconds"
#     },
#     {
#       "start_ms": 1229000,
#       "snippet": "just reassurances. The boy afraid that they're going to die and the father correcting him and then saying that if the boy were to die, his father would be right behind him to make sure he's safe.",
#       "start_time_text": "20:29",
#       "start_time_label": "20 minutes, 29 seconds"
#     },
#     {
#       "start_ms": 1238000,
#       "snippet": "There's a few moments that most often happen after the father and son have a conversation where it seems McCarthy",
#       "start_time_text": "20:38",
#       "start_time_label": "20 minutes, 38 seconds"
#     },
#     {
#       "start_ms": 1245000,
#       "snippet": "kind of muses on the nature of this all semi from the father's perspective but also semi from some greater omnisient",
#       "start_time_text": "20:45",
#       "start_time_label": "20 minutes, 45 seconds"
#     },
#     {
#       "start_ms": 1253000,
#       "snippet": "narrator's perspective. Like here's the first one after that conversation. He lay listening to the water drip in the woods bedrock. This the cold and the",
#       "start_time_text": "20:53",
#       "start_time_label": "20 minutes, 53 seconds"
#     },
#     {
#       "start_ms": 1263000,
#       "snippet": "silence. The ashes of the late world carried on the bleak and temporal winds to and fro in the void. Carried forth and scattered carried forth again.",
#       "start_time_text": "21:03",
#       "start_time_label": "21 minutes, 3 seconds"
#     },
#     {
#       "start_ms": 1274000,
#       "snippet": "Everything uncoupled from its shoring unsupported in the ash and air sustained by a breath trembling brief.",
#       "start_time_text": "21:14",
#       "start_time_label": "21 minutes, 14 seconds"
#     },
#     {
#       "start_ms": 1283000,
#       "snippet": "If only my heart were stone.",
#       "start_time_text": "21:23",
#       "start_time_label": "21 minutes, 23 seconds"
#     },
#     {
#       "start_ms": 1287000,
# ...
#       "snippet": "Because that several of the themes of the book are applicable to the real world. Yes, the world does have terrible things in it. Yes, things will be bad,",
#       "start_time_text": "3:51:16",
#       "start_time_label": "3 hours, 51 minutes, 16 seconds"
#     },
#     {
#       "start_ms": 13883000,
#       "snippet": "but that doesn't mean the fire doesn't exist. that doesn't mean it's not worth pushing on. From our opening lines of the story, the father says this is his",
#       "start_time_text": "3:51:23",
#       "start_time_label": "3 hours, 51 minutes, 23 seconds"
#     },
#     {
#       "start_ms": 13891000,
#       "snippet": "commission from God to take care of this child. And in the final lines of the story, the woman tells the boy that his father might as well have been the voice of God. I mean, what would God have done",
#       "start_time_text": "3:51:31",
#       "start_time_label": "3 hours, 51 minutes, 31 seconds"
#     },
#     {
#       "start_ms": 13899000,
#       "snippet": "if not take care of him? And that through history, there were people who carried the fire, people who were the voice of God, passing on goodness to their sons and daughters. God and his",
#       "start_time_text": "3:51:39",
#       "start_time_label": "3 hours, 51 minutes, 39 seconds"
#     },
#     {
#       "start_ms": 13908000,
#       "snippet": "oracles watched over them from the outset of their journey. And along the way, anytime it was too hard, it was made right again. And ultimately, when",
#       "start_time_text": "3:51:48",
#       "start_time_label": "3 hours, 51 minutes, 48 seconds"
#     },
#     {
#       "start_ms": 13916000,
#       "snippet": "the father wasn't there to watch him, he sent his angels into the picture.",
#       "start_time_text": "3:51:56",
#       "start_time_label": "3 hours, 51 minutes, 56 seconds"
#     },
#     {
#       "start_ms": 13919000,
#       "snippet": "Whatever higher power exists in this universe had to be sure that the fire made it out. Because regardless of time, regardless of what state the world is,",
#       "start_time_text": "3:51:59",
#       "start_time_label": "3 hours, 51 minutes, 59 seconds"
#     },
#     {
#       "start_ms": 13927000,
#       "snippet": "whether it be right now or in a post-apocalypse, what else matters? I think this idea of divinity, of some grand design, is perfectly encapsulated in that final paragraph in the book.",
#       "start_time_text": "3:52:07",
#       "start_time_label": "3 hours, 52 minutes, 7 seconds"
#     },
#     {
#       "start_ms": 13938000,
#       "snippet": "talks about how there were trout that were in the mountains. That on the speckles of their back, the mazes and maps of the world were predestined long",
#       "start_time_text": "3:52:18",
#       "start_time_label": "3 hours, 52 minutes, 18 seconds"
#     },
#     {
#       "start_ms": 13946000,
#       "snippet": "before humanity got there. Long before we knew to look, it was already written out. The world may be a maze. It may be treacherous and it may be scary. And a",
#       "start_time_text": "3:52:26",
#       "start_time_label": "3 hours, 52 minutes, 26 seconds"
#     },
#     {
#       "start_ms": 13954000,
#       "snippet": "lot of us won't be around for the end of it, but in the end, goodness finds the boy. Cormick McCarthy ties a lot of themes from one of his stories into the",
#       "start_time_text": "3:52:34",
#       "start_time_label": "3 hours, 52 minutes, 34 seconds"
#     },
#     {
#       "start_ms": 13962000,
#       "snippet": "next. And the story that he wrote before he wrote The Road was No Country for Old Men. originally developed as a screenplay and then as a novel. I talked",
#       "start_time_text": "3:52:42",
#       "start_time_label": "3 hours, 52 minutes, 42 seconds"
#     },
#     {
#       "start_ms": 13970000,
#       "snippet": "about this in one of the earliest videos in my channel, but at the end of No Country for Old Men, the sheriff has a dream of his father riding on horseback",
#       "start_time_text": "3:52:50",
#       "start_time_label": "3 hours, 52 minutes, 50 seconds"
#     },
#     {
#       "start_ms": 13978000,
#       "snippet": "through the mountains. And in that dream, Sheriff Bell says he saw his father carrying a fire out into the dark, out into the cold. That symbolism",
#       "start_time_text": "3:52:58",
#       "start_time_label": "3 hours, 52 minutes, 58 seconds"
#     },
#     {
#       "start_ms": 13987000,
#       "snippet": "has its own weight in that story, but it's so clear how it's applied to this one. Our fathers and their fathers and their fathers before them all carried the fire. Now, in a world of misery,",
#       "start_time_text": "3:53:07",
#       "start_time_label": "3 hours, 53 minutes, 7 seconds"
#     },
#     {
#       "start_ms": 13997000,
#       "snippet": "especially when there's misery and monsters and things that go bump in the night, who are we to make sure that the torch doesn't keep going? And if that",
#       "start_time_text": "3:53:17",
#       "start_time_label": "3 hours, 53 minutes, 17 seconds"
#     },
#     {
#       "start_ms": 14004000,
#       "snippet": "fire is so important, if it's so important that it bends the voice and ear of God, then how could goodness not find it? The road is not hopeful in spite of its setting, but because of it.",
#       "start_time_text": "3:53:24",
#       "start_time_label": "3 hours, 53 minutes, 24 seconds"
#     },
#     {
#       "start_ms": 14015000,
#       "snippet": "In a world so miserable, so close to humanity's extinction, the same thing that matters is what's always mattered.",
#       "start_time_text": "3:53:35",
#       "start_time_label": "3 hours, 53 minutes, 35 seconds"
#     },
#     {
#       "start_ms": 14022000,
#       "snippet": "The carriers of something so sacred will always be sacred, or especially in a world that's forgot what that means.",
#       "start_time_text": "3:53:42",
#       "start_time_label": "3 hours, 53 minutes, 42 seconds"
#     },
#     {
#       "start_ms": 14028000,
#       "snippet": "It's for these reasons that The Road is my favorite book. Not only is it an interesting setting with interesting characters and dialogues and themes, but",
#       "start_time_text": "3:53:48",
#       "start_time_label": "3 hours, 53 minutes, 48 seconds"
#     },
#     {
#       "start_ms": 14037000,
#       "snippet": "it so perfectly executes those uses the theme of fire, the father and son looking out for each other, and it",
#       "start_time_text": "3:53:57",
#       "start_time_label": "3 hours, 53 minutes, 57 seconds"
#     },
#     {
#       "start_ms": 14044000,
#       "snippet": "weaves all of those into this idea of a grander purpose of walking through misery, but with something that matters.",
#       "start_time_text": "3:54:04",
#       "start_time_label": "3 hours, 54 minutes, 4 seconds"
#     },
#     {
#       "start_ms": 14050000,
#       "snippet": "It's a book about endurance, about purpose, about love and hope. And it's a story that I appreciate more every time I come back to it. Like I said, it's one",
#       "start_time_text": "3:54:10",
#       "start_time_label": "3 hours, 54 minutes, 10 seconds"
#     },
#     {
#       "start_ms": 14059000,
#       "snippet": "I've been nervous to cover because it means so much to me. But hopefully I was able to get that across at least a little bit and do the story some",
#       "start_time_text": "3:54:19",
#       "start_time_label": "3 hours, 54 minutes, 19 seconds"
#     },
#     {
#       "start_ms": 14067000,
#       "snippet": "justice. And hopefully you've read the story first and didn't let this be your first experience. But even if you did that, hopefully now it means something to you. The Road is one of those books",
#       "start_time_text": "3:54:27",
#       "start_time_label": "3 hours, 54 minutes, 27 seconds"
#     },
#     {
#       "start_ms": 14075000,
#       "snippet": "that I think a lot of people have heard of, but not as many have read. Sure, in older generations and in times past, I mean, it's incredibly famous book. A lot",
#       "start_time_text": "3:54:35",
#       "start_time_label": "3 hours, 54 minutes, 35 seconds"
#     },
#     {
#       "start_ms": 14083000,
#       "snippet": "of people have read it, but its reputation certainly exceeds it. But as with any other McCarthy story, I think it's one worth reading and one worth dwelling on. So hopefully you guys",
#       "start_time_text": "3:54:43",
#       "start_time_label": "3 hours, 54 minutes, 43 seconds"
#     },
#     {
#       "start_ms": 14092000,
#       "snippet": "enjoyed it. Hopefully this all meant something to you. And I just want to say thank you for watching. There are some other adaptations of The Road that I think are interesting. For example,",
#       "start_time_text": "3:54:52",
#       "start_time_label": "3 hours, 54 minutes, 52 seconds"
#     },
#     {
#       "start_ms": 14100000,
#       "snippet": "there's the visual novel uh that was illustrated by Manu Larsenette. I have a copy of that and it's pretty cool for visualizing a lot of the things in the",
#       "start_time_text": "3:55:00",
#       "start_time_label": "3 hours, 55 minutes"
#     },
#     {
#       "start_ms": 14107000,
#       "snippet": "book. If you're a fan of the book, I highly recommend it. And there's also the John Hillcoat film that's pretty good. Uh VGO Mortonson does a fantastic",
#       "start_time_text": "3:55:07",
#       "start_time_label": "3 hours, 55 minutes, 7 seconds"
#     },
#     {
#       "start_ms": 14115000,
#       "snippet": "job playing the father. Uh the movie has now sadly late and great Robert Duval in it playing the old man. But while it's",
#       "start_time_text": "3:55:15",
#       "start_time_label": "3 hours, 55 minutes, 15 seconds"
#     },
#     {
#       "start_ms": 14123000,
#       "snippet": "good and John Hill was the director of it, he's the guy who's currently slated to direct Blood Meridian. So, you know,",
#       "start_time_text": "3:55:23",
#       "start_time_label": "3 hours, 55 minutes, 23 seconds"
#     },
#     {
#       "start_ms": 14129000,
#       "snippet": "I want to hype that guy up because I want that movie to be good. There's so much you have to change from a literary",
#       "start_time_text": "3:55:29",
#       "start_time_label": "3 hours, 55 minutes, 29 seconds"
#     },
#     {
#       "start_ms": 14136000,
#       "snippet": "to a visual adaptation of the story that while it's good, I don't think it really holds a candle to the book. Just cuz I",
#       "start_time_text": "3:55:36",
#       "start_time_label": "3 hours, 55 minutes, 36 seconds"
#     },
#     {
#       "start_ms": 14142000,
#       "snippet": "mean, how in a movie do you portray the instances of the writer almost coming out of the page to speak to the father and to speak to the reader or these",
#       "start_time_text": "3:55:42",
#       "start_time_label": "3 hours, 55 minutes, 42 seconds"
#     },
#     {
#       "start_ms": 14151000,
#       "snippet": "musings the father has to himself evoking everything from Job when he says, \"Curse God and die to muses to old",
#       "start_time_text": "3:55:51",
#       "start_time_label": "3 hours, 55 minutes, 51 seconds"
#     },
#     {
#       "start_ms": 14158000,
#       "snippet": "epics.\" I mean, the book itself really feels like another odyssey. You have the father and son traveling on this long voyage, coming across sights and horrors",
#       "start_time_text": "3:55:58",
#       "start_time_label": "3 hours, 55 minutes, 58 seconds"
#     },
#     {
#       "start_ms": 14167000,
#       "snippet": "as they go. And you get some of that when you watch the film, but you don't really get the choir part of it, right?",
#       "start_time_text": "3:56:07",
#       "start_time_label": "3 hours, 56 minutes, 7 seconds"
#     },
#     {
#       "start_ms": 14173000,
#       "snippet": "The part where the story reminisces or really brings up its themes that enhance everything else you're reading. It's just a piece that's so perfectly adapted",
#       "start_time_text": "3:56:13",
#       "start_time_label": "3 hours, 56 minutes, 13 seconds"
#     },
#     {
#       "start_ms": 14182000,
#       "snippet": "to a novel that it's hard for me to see how you could even translate it to a visual format. As a matter of fact,",
#       "start_time_text": "3:56:22",
#       "start_time_label": "3 hours, 56 minutes, 22 seconds"
#     },
#     {
#       "start_ms": 14189000,
#       "snippet": "here's a hot take. I honestly think a Blood Meridian adaptation would hypothetically do better than a road adaptation because a lot of the things",
#       "start_time_text": "3:56:29",
#       "start_time_label": "3 hours, 56 minutes, 29 seconds"
#     },
#     {
#       "start_ms": 14197000,
#       "snippet": "in Blood Meridian are moments of dialogue or visuals that are described.",
#       "start_time_text": "3:56:37",
#       "start_time_label": "3 hours, 56 minutes, 37 seconds"
#     },
#     {
#       "start_ms": 14201000,
#       "snippet": "These are things that can be illustrated on screen, whereas a lot of the stuff in the road is internal monologues or thoughts or sometimes the book musing on",
#       "start_time_text": "3:56:41",
#       "start_time_label": "3 hours, 56 minutes, 41 seconds"
#     },
#     {
#       "start_ms": 14209000,
#       "snippet": "what's happening. So again, I don't hate the movie. I think it's pretty cool. If you're a fan of the book, it's certainly worth watching. But yeah, if you couldn't tell, there's not really",
#       "start_time_text": "3:56:49",
#       "start_time_label": "3 hours, 56 minutes, 49 seconds"
#     },
#     {
#       "start_ms": 14217000,
#       "snippet": "anything that beats this for me. All in all, I've talked for long enough. I hope you guys enjoyed this video. There will be new videos on the way soon. I",
#       "start_time_text": "3:56:57",
#       "start_time_label": "3 hours, 56 minutes, 57 seconds"
#     },
#     {
#       "start_ms": 14224000,
#       "snippet": "promise. Being a father now has caused quite a change in my daily routine, so forgive me if I'm a little behind on some stuff, but hopefully it'll be worth",
#       "start_time_text": "3:57:04",
#       "start_time_label": "3 hours, 57 minutes, 4 seconds"
#     },
#     {
#       "start_ms": 14232000,
#       "snippet": "it when it comes out. And hopefully this video was worth it. I'm certainly nervous and can't wait for everyone to rip me apart for talking about this",
#       "start_time_text": "3:57:12",
#       "start_time_label": "3 hours, 57 minutes, 12 seconds"
#     },
#     {
#       "start_ms": 14239000,
#       "snippet": "story, but oops. They can say I'm bad at literary analysis. They can say I shouldn't be talking about these stories, but what they can't say is I don't got the gumption for it. I mean,",
#       "start_time_text": "3:57:19",
#       "start_time_label": "3 hours, 57 minutes, 19 seconds"
#     },
#     {
#       "start_ms": 14250000,
#       "snippet": "they could say that, but that's probably like the third or fourth thing they'll pick. All in all, I believe that should do it for now. But before I go, I just want to say thank you for watching. I",
#       "start_time_text": "3:57:30",
#       "start_time_label": "3 hours, 57 minutes, 30 seconds"
#     },
#     {
#       "start_ms": 14258000,
#       "snippet": "hope that you enjoyed, especially on a video that means so much to me, and I'll see you in the next one. [snorts] Bye.",
#       "start_time_text": "3:57:38",
#       "start_time_label": "3 hours, 57 minutes, 38 seconds"
#     },
#     {
#       "start_ms": 14267000,
#       "snippet": "Or not really. The video means so much to me. I mean, this is a video I made.",
#       "start_time_text": "3:57:47",
#       "start_time_label": "3 hours, 57 minutes, 47 seconds"
#     },
#     {
#       "start_ms": 14271000,
#       "snippet": "The story I made the video about means so much to me. Not my own video. That sounds pretentious, which I am a",
#       "start_time_text": "3:57:51",
#       "start_time_label": "3 hours, 57 minutes, 51 seconds"
#     },
#     {
#       "start_ms": 14279000,
#       "snippet": "YouTuber, so you know, fair enough.",
#       "start_time_text": "3:57:59",
#       "start_time_label": "3 hours, 57 minutes, 59 seconds"
#     }
#   ]
# }

# %%
for result in response.get("transcript", []):
    snippet = result.get("snippet")
    start_time_text = result.get("start_time_text")

    print(f"SnippetL: {snippet}")
    print(f"Start Time: {start_time_text}")
    print("-" * 10)
# Out:
# SnippetL: When he woke in the woods, in the dark and the cold of the night, he'd reach out to touch the child sleeping beside him. Nights dark beyond darkness, and
# Start Time: 0:00
# ----------
# SnippetL: the days more gray, each one what had gone before, like the onset of some cold glaucoma, dimming away the world. His
# Start Time: 0:08
# ----------
# SnippetL: hand rose and fell softly with each precious breath. He pushed away the plastic tarpulin and raised himself in
# Start Time: 0:17
# ----------
# SnippetL: the stinking robes and blankets and looked toward the east for any light,
# Start Time: 0:24
# ----------
# SnippetL: but there was none. In the dream from which he'd wakened, he had wandered in a cave where the child led him by the hand. Their light plain over the wet
# Start Time: 0:28
# ----------
# SnippetL: flow stone walls, like pilgrims in a fable, swallowed up and lost among the inward parts of some grrenitic beast.
# Start Time: 0:37
# ----------
# SnippetL: Deep stone flues where the water dripped and sang tolling in the silence the minutes of the earth and the hours and the days of it years without cease.
# Start Time: 0:45
# ----------
# SnippetL: Till they stood in a great stone room where lay a black and ancient lake. And on the far shore a creature that raised
# Start Time: 0:55
# ----------
# SnippetL: its dripping mouth from the rimstone pool and stared into the light with eyes dead white and sightless as the eggs of spiders.
# Start Time: 1:02
# ----------
# SnippetL: It swung its head low over the water as if to take the sin of what it could not see. Crouching there, pale and naked and
# Start Time: 1:12
# ----------
# SnippetL: translucent, its alabaster bones cast up in shadow on the rocks behind it. Its boughels, its beating heart, the brain
# Start Time: 1:19
# ----------
# SnippetL: that pulsed in a dull glass bell. It swung its head from side to side and then gave out a low moan and turned and
# Start Time: 1:28
# ----------
# SnippetL: lurched away and loped soundlessly into the dark.
# Start Time: 1:36
# ----------
# SnippetL: In my junior year of high school, our English and literature class had a focus on American literature, specifically many of the famous American poets. So that year, we covered Dickinson,
# Start Time: 1:41
# ----------
# SnippetL: Emerson, Poe. But as with most high school English classes, there were some novels thrown in throughout the year that we were supposed to read and write
# Start Time: 1:52
# ----------
# SnippetL: book reports on. And some of the books we read that year were interesting, like Lord of the Flies and Hatchet. But for reasons I'm sure a lot of you can relate
# Start Time: 1:59
# ----------
# SnippetL: to. I think a lot of my enjoyment for those stories was pulled away because it was homework. Also, importantly, I was 16 and stupid. But, you know, even the
# Start Time: 2:07
# ----------
# SnippetL: best of stories can come off as a drag sometimes if you're being forced to do them. But, there was one book we read that year that that didn't apply to. My
# Start Time: 2:16
# ----------
# SnippetL: junior English teacher was a man named Mr. Lockhart. And there was one book that he had taught years before in his previous American literature course that
# Start Time: 2:24
# ----------
# SnippetL: when he got this new class, my class, he demanded he could teach again. This intrigued me for a couple reasons. For one, it's weird to see a teacher so
# Start Time: 2:31
# ----------
# SnippetL: passionate to get one specific book into the curriculum. And two, I had heard about this book before. Because as a
# Start Time: 2:40
# ----------
# SnippetL: young kid into creepy pastas and scary movies and spooky stories, many regarded this book as one of the darkest stories ever written. Not to mention that some
# Start Time: 2:47
# ----------
# SnippetL: parts of the book were set in the town that I grew up. So if all those details had my interest, what hooked it was the first day we talked about the book. I
# Start Time: 2:56
# ----------
# SnippetL: remember so distinctly Mr. Lockheart standing in front of the class and reading a few of the lines from the first pages of the story. And as he did,
# Start Time: 3:04
# ----------
# SnippetL: he began to cry, apologizing to the class and saying that this story is one that's very powerful to him and one that's very impactful to any father. For
# Start Time: 3:13
# ----------
# SnippetL: the first time I could remember, I was excited to do my homework and I went home that night and read the entire book. That story became what is still
# Start Time: 3:22
# ----------
# SnippetL: today my favorite book and it introduced me to my favorite author. But more than that, it ignited an already kindling love of stories that I had into a fire.
# Start Time: 3:29
# ----------
# SnippetL: That fire continued to burn until I had to make a YouTube channel to talk about some of my favorites. So, my favorite book and the one that directly led me to
# Start Time: 3:40
# ----------
# SnippetL: talking in front of a camera to you all now is Cormick McCarthy's The Road. The Road is a story that's so special to me, I've been hesitant to talk about it.
# Start Time: 3:48
# ----------
# SnippetL: Sure, I've talked about McCarthy's other works like No Country for Old Men and Blood Meridian, the second of which being one of the most popular videos on
# Start Time: 3:56
# ----------
# SnippetL: the channel. But anytime I would think about talking about the road, I'd be almost scared to. Like, how do you talk about something that means so much to you personally? I mean, what if you miss something or you get something wrong?
# Start Time: 4:04
# ----------
# SnippetL: But as many of you know, I recently became a father. And one of the core points of this book is fatherhood. So, I guess now is as good of a time as ever.
# Start Time: 4:14
# ----------
# SnippetL: And I should probably also tell you what this book's about. The road follows a father and son as they make their way through a post-apocalyptic America. We
# Start Time: 4:22
# ----------
# SnippetL: get some clues as to what the apocalypse might have been, but for the sake of the story, it doesn't matter. What matters is the relationship between the father
# Start Time: 4:30
# ----------
# SnippetL: and son as they brave this horrifying new world. a world full of such terrible occurrences that it's given the book the reputation as one of the darkest stories
# Start Time: 4:37
# ----------
# SnippetL: ever written, which I'm going to give a big viewer discretion to this whole video. The book deals with topics like cannibalism and child death and other
# Start Time: 4:46
# ----------
# SnippetL: things you've come to know and love on this channel. I would never call the book gratuitous, especially because of the context in which these events show
# Start Time: 4:55
# ----------
# SnippetL: up, but it is there if you're sensitive to that. And of course, most importantly, The Road to Me is a very important book. It's a once in
# Start Time: 5:03
# ----------
# SnippetL: a-lifetime experience, and it's not one that I want to ruin for you. So, there will be a link to the book in the description below. Please check it out
# Start Time: 5:11
# ----------
# SnippetL: for yourself first, and then come back and we can talk about it. Stories like this are too important to let your first experience be made murky with someone's
# Start Time: 5:19
# ----------
# SnippetL: interpretation. But aside from just the literal events described, the philosophy of the book is so interesting. sometimes conveyed through dreams like what you
# Start Time: 5:26
# ----------
# SnippetL: heard at the start of the video, the opening words of the book, sometimes hinted through characters and dialogue.
# Start Time: 5:34
# ----------
# SnippetL: It all comes together to create a narrative that is so cohesive and compelling that I am equally excited as I am nervous to talk about it. So
# Start Time: 5:39
# ----------
# SnippetL: hopefully you decide to talk about it with me. And if all this sounds interesting to you, then stick around after the ad as we talk about the misery and fire of Cormick McCarthy's The Road.
# Start Time: 5:47
# ----------
# SnippetL: While it might be fun to read about someone starving to death, you shouldn't do that to yourself. But now, healthy, delicious meals have never been easier.
# Start Time: 5:57
# ----------
# SnippetL: Thanks to today's sponsor, Factor. Factor delivers fresh, never frozen,
# Start Time: 6:05
# ----------
# SnippetL: chef crafted, and dietitian approved meals straight to your door. They're ready to heat and eat in just 2 minutes,
# Start Time: 6:09
# ----------
# SnippetL: and they're designed to support your wellness journey. Factor can help eliminate the stress around cooking,
# Start Time: 6:15
# ----------
# SnippetL: planning, or cleanup, so you can stay focused on your goals. Every week,
# Start Time: 6:20
# ----------
# SnippetL: Factor has over 100 rotating meal options. and not just meals, but things like salads, shakes, breakfast, and more. They're doubling up on things like
# Start Time: 6:23
# ----------
# SnippetL: their protein options and their seafood options. And they can accommodate any dietary restriction you have, such as keto, gluten, or you can even swap
# Start Time: 6:32
# ----------
# SnippetL: protein options to fit whatever is right for you. And as I mentioned, there's virtually no prep or cleanup as they're ready to make in just 2 minutes. Most of
# Start Time: 6:39
# ----------
# SnippetL: us get short on time, so we neglect our health in order to eat something that's cheap and quick. But now you can have something that's cheap and quick and
# Start Time: 6:47
# ----------
# SnippetL: good for you and tastes really good as well. Backtor will send me meals for things that I think have no business being in the microwave. Things like fish
# Start Time: 6:54
# ----------
# SnippetL: or tofu or steak. Somehow whatever they're doing to their food just works.
# Start Time: 7:01
# ----------
# SnippetL: And I believe a lot of it comes down to their food quality. Factor bans over 175 ingredients. Things like refined seed oils or artificial sugars in order to
# Start Time: 7:05
# ----------
# SnippetL: give you nutrient-dense foods that focused on your energy and health. As of late, Factor hasn't sent me a meal I haven't liked. It feels like I'm having
# Start Time: 7:14
# ----------
# SnippetL: a cheat day without the guilt. So, if you want to get in on this fantastic product, then now's the perfect time.
# Start Time: 7:22
# ----------
# SnippetL: That's because if you head to factor75.com or click the link in the description and use code windagon FB50, you'll get 50%
# Start Time: 7:27
# ----------
# SnippetL: off your first Factor box plus free breakfast for a year. That's right, half off your first box and free breakfast
# Start Time: 7:34
# ----------
# SnippetL: for a year while your subscription lasts. Again, head to the link in the description at factor75.com and use code windagonf50 to get in on this incredible
# Start Time: 7:42
# ----------
# SnippetL: offer today. Thank you all for watching the ad. Thank you to Factor for sponsoring the channel. Their link will be in the description. We are now back
# Start Time: 7:50
# ----------
# SnippetL: to the video. We are going to go ahead and get into it, but as always, thank you for watching. Also, I feel like I should point out uh I'm not just wearing
# Start Time: 7:57
# ----------
# SnippetL: a bandage to like cosplay. I wrecked a dirt bike because I'm stupid. But if there ever was a time to be stupid, it
# Start Time: 8:06
# ----------
# SnippetL: would be now because it matches the aesthetics for this video. Anyway, in the opening of the book is a dedication
# Start Time: 8:14
# ----------
# SnippetL: to Cor McCarthy's son, John Francis McCarthy. John was born in 1999,
# Start Time: 8:21
# ----------
# SnippetL: according to the internet. So, at the time of the book's publication, he would have been 6 or 7 years old. Because of that, it's apparent, as Corormick would
# Start Time: 8:26
# ----------
# SnippetL: later go on to state, that his relationship with his son was his influence for the story. We already got some of the key ideas of the book out of
# Start Time: 8:34
# ----------
# SnippetL: the way in the introduction. The world is dark in a way that's hard to imagine.
# Start Time: 8:41
# ----------
# SnippetL: We'll later see that the sun itself is blotted out by a gray sky. So, if the day is that dark, you could imagine how dark it is at night. Dark beyond dark,
# Start Time: 8:45
# ----------
# SnippetL: as the story says. The condition of the man and the boy is dire. Food, as you can imagine, is scarce. The world has been like this for some years now. Their
# Start Time: 8:54
# ----------
# SnippetL: clothes and blankets stink. Filth upon filth. Years of rot and decay. We can imagine the two of them emaciated and
# Start Time: 9:02
# ----------
# SnippetL: suffering and not too far from dead. But in the midst of this misery, there's a light. The light being the boy,
# Start Time: 9:10
# ----------
# SnippetL: something that's personified in the father's first dream. He walks through a dark cave as the child's light guides him. But regardless of the light,
# Start Time: 9:15
# ----------
# SnippetL: there's something monstrous in here.
# Start Time: 9:22
# ----------
# SnippetL: Something horrific, growling, and ancient. At the back of this cave, or this world he finds himself in in the dream, the boy is precious, but there's
# Start Time: 9:24
# ----------
# SnippetL: a monster around the corner. We have further clues to the state of the world in the first lines after the dream. With the first gray light, he rose and left
# Start Time: 9:32
# ----------
# SnippetL: the boy sleeping and walked out to the road and squatted and studied the country to the south, barren, silent,
# Start Time: 9:39
# ----------
# SnippetL: godless. He thought the month was October, but he wasn't sure. He hadn't kept a calendar for years. They were
# Start Time: 9:47
# ----------
# SnippetL: moving south. There'd be no surviving another winter here. As I said, no one's seen the sun for years. Along with the darkness, the world has brought a
# Start Time: 9:54
# ----------
# SnippetL: coldness to it. As we'll see, everywhere it seems to snow and freeze, but in the north, winters are particularly rough.
# Start Time: 10:03
# ----------
# SnippetL: So, with no other objective, the man and his boy are going south. There's a few narrative dynamics that need no introduction. Like, in several
# Start Time: 10:10
# ----------
# SnippetL: instances, it's the job of the writer to make you care about characters within a story, or at least care about their relationship. If we're introduced to two
# Start Time: 10:18
# ----------
# SnippetL: people, the story needs to establish if they hate each other, love each other,
# Start Time: 10:26
# ----------
# SnippetL: if they're here by their own decisions or someone else's, etc. But there's a few relationships that kind of cut through the red tape. For example, if
# Start Time: 10:30
# ----------
# SnippetL: you show a husband and wife, it's assumed that they like each other. The same can be said about brother and sister, mother and daughter, and father
# Start Time: 10:38
# ----------
# SnippetL: and son. Now, obviously, these relationships don't have to be typical.
# Start Time: 10:45
# ----------
# SnippetL: The writer can subvert expectations wherever they want. But when we hear those titles, we naturally assume a bond. So with his father taking his son
# Start Time: 10:48
# ----------
# SnippetL: to the south, normally that would be all we need to assume these two care about each other. But in spite of that,
# Start Time: 10:56
# ----------
# SnippetL: McCarthy gives one of the most powerful mandates that I think I've ever heard in a story. After looking at the countryside through his binoculars, the
# Start Time: 11:02
# ----------
# SnippetL: story says he lowered the glasses and pulled down the cotton mask from his face and wiped his nose on the back of his wrist and then glassed the country
# Start Time: 11:10
# ----------
# SnippetL: again. Then he just sat there holding the binoculars and watching the ash and daylight congeal over the land. He knew
# Start Time: 11:18
# ----------
# SnippetL: only that the child was his warrant. He said, "If he is not the word of God, God never spoke." Earlier when I said my
# Start Time: 11:25
# ----------
# SnippetL: junior English teacher cried reading the opening lines of the story, this is the line he cried during. It is such a powerful line that so succinctly
# Start Time: 11:34
# ----------
# SnippetL: encapsulates the idea that our father is setting out with. The world is empty. it is dead and there is no good to be had.
# Start Time: 11:42
# ----------
# SnippetL: But if there is a god, then he looks like that. It gives us the idea that the father isn't doing all of this just to save his son, but for some greater
# Start Time: 11:49
# ----------
# SnippetL: purpose for humanity's sake, as if the child himself is a vessel. He's the last carrier of something that the world seems to have forgotten. This idea of
# Start Time: 11:58
# ----------
# SnippetL: God, or the closest thing we have to God, will continue throughout the story.
# Start Time: 12:06
# ----------
# SnippetL: Also, the father and the son will never be named. They are simply called the man and the boy. McCarthy does this a lot in his works. Like the protagonist from
# Start Time: 12:10
# ----------
# SnippetL: Blood Meridian was just known as the kid. Because in that story, his name didn't matter. He was the witness. His inclusion, if there was any in the
# Start Time: 12:19
# ----------
# SnippetL: atrocities the Glanton gang committed was omitted. Because the core of the story was about how everything affected him. If the things he saw changed him as
# Start Time: 12:27
# ----------
# SnippetL: a person for better or worse by the time of the story's end. In that way, the kid was a stand-in for something greater. a pseudonym for true humanity that
# Start Time: 12:35
# ----------
# SnippetL: witnessed atrocities and allowed them to pass by without delay. Because of that,
# Start Time: 12:43
# ----------
# SnippetL: he doesn't need a name. He's just the kid. And here in this story, the man and the boy are much the same, but we'll talk about how later. We get some
# Start Time: 12:47
# ----------
# SnippetL: description as to how the two of them live. All of their belongings are in a grocery cart, one they undoubtedly scavenge from some decrepit grocery
# Start Time: 12:55
# ----------
# SnippetL: store and now used to haul all of their belongings, from tarbs to old cornmeal cakes. Food is scarce, but the man rations what food he has between him and
# Start Time: 13:02
# ----------
# SnippetL: the boy. Much of the dialogue between the man and the boy feels authentic.
# Start Time: 13:11
# ----------
# SnippetL: There are very few moments of them pondering things or telling stories or describing the world around them. I mean, they've been in this world for
# Start Time: 13:15
# ----------
# SnippetL: years now. Any conversation like that they've already had. Instead, most of their dialogue is simply what it needs to be, reassurances. The boy turned in the blankets, then he opened his eyes.
# Start Time: 13:23
# ----------
# SnippetL: "Hi, Papa," he said. I'm right here. I know.
# Start Time: 13:34
# ----------
# SnippetL: Just a simple assurance that the father is here and the boy is safe. This is also a good time to point out if you're not familiar with McCarthy's work that
# Start Time: 13:39
# ----------
# SnippetL: he doesn't like punctuation. Like straight up, he has said before, "Why would I want to cover up the page in silly little marks, so he just doesn't
# Start Time: 13:46
# ----------
# SnippetL: do it." I didn't even know you could do that before I started reading his stuff.
# Start Time: 13:54
# ----------
# SnippetL: If you don't like quotation marks or colons or semicolons, you just pretend like they don't exist, I guess. Because of that, moments of dialogue like that
# Start Time: 13:58
# ----------
# SnippetL: are just text on the page that occurs after each other. The only indicator we get that the speaker has switched is a new indent. But because of the way
# Start Time: 14:05
# ----------
# SnippetL: different characters speak and flow in dialogue, it's not really confusing as to who's talking. Now, sure, part of that is McCarthy's skill as a writer,
# Start Time: 14:13
# ----------
# SnippetL: but also like 99% of the dialogue is between a grown man and a child, so there's normally not a lot of wiggle
# Start Time: 14:22
# ----------
# SnippetL: room. The father pushes the grocery cart that has an old motorcycle mirror attached to it. That way, he can always keep his eyes forward, but have an idea if something's coming behind them.
# Start Time: 14:30
# ----------
# SnippetL: Animals in this world seem to be completely extinct. But there's other people out there. In addition to that,
# Start Time: 14:40
# ----------
# SnippetL: both he and the boy have on a backpack to carry essential things in case they need to ditch the shopping cart. The only weapon they have is an old
# Start Time: 14:46
# ----------
# SnippetL: revolver, a revolver of which they only have two bullets. As they press on into the day, the story says, "Then they set out along the black top in the gunmetal
# Start Time: 14:54
# ----------
# SnippetL: light, shuffling through the ash. Each the others swirled entire." The only translator understanding the boy has for
# Start Time: 15:02
# ----------
# SnippetL: the world around him, is the man. And the only thing that makes sense to the man, the only thing worth pushing on for is the boy. The two need each other in a way that's hard to put into words.
# Start Time: 15:10
# ----------
# SnippetL: There's also the mention of them shuffling through the ash. Again, we don't know exactly how this apocalypse happened, but we know it involved a lot of fire, or the very least, it caused a
# Start Time: 15:20
# ----------
# SnippetL: lot of fire. Perhaps a meteor hit the Earth. Perhaps there was some massive solar event. Perhaps a nuclear war.
# Start Time: 15:28
# ----------
# SnippetL: Whatever it is, it killed all plant life, killed out all animal life, and has almost killed out all human life. In addition to this, ash rains around the
# Start Time: 15:35
# ----------
# SnippetL: world constantly like snow. It hangs in the air and coats everything. In most apocalyptic stories, there is a hope for a world beyond, regardless if it's
# Start Time: 15:44
# ----------
# SnippetL: zombies or a disease outbreak or natural disasters. These stories are normally underlined by the idea of a reward at
# Start Time: 15:52
# ----------
# SnippetL: the end of perseverance. If I can get through this, things will get better. If I can get through this, humanity will be okay. But the road's unique in the idea that nothing will ever be okay again.
# Start Time: 15:59
# ----------
# SnippetL: Humanity is not dying. We are extinct.
# Start Time: 16:10
# ----------
# SnippetL: And the survivors just haven't got that memo yet. Now, it's not like the road is the only story to have an inevitable extinction of humanity. Given some of
# Start Time: 16:13
# ----------
# SnippetL: the things we're going to see, it's certainly one of the most depressing. As they're walking, the two of them come to an old gas station. Everything there's been looted. If not in the immediate aftermath of this apocalyptic event,
# Start Time: 16:20
# ----------
# SnippetL: then in the years since of other travelers like themselves passing by.
# Start Time: 16:31
# ----------
# SnippetL: However, as they're making their way through the gas station, the story says this. He went into the office, dust and ash everywhere. The boy stood in the
# Start Time: 16:35
# ----------
# SnippetL: door. a metal desk, cash register, some old automotive manuals, swollen and soden. The lenolum was stained and
# Start Time: 16:43
# ----------
# SnippetL: curling from the leaking roof. He crossed to the desk and stood there.
# Start Time: 16:51
# ----------
# SnippetL: Then he picked up the phone and dialed the number of his father's house in that long ago. The boy watched him. "What are
# Start Time: 16:56
# ----------
# SnippetL: you doing?" he said. This is such an interesting little moment and one that I haven't seen discussed enough regarding
# Start Time: 17:04
# ----------
# SnippetL: this book because there's this subtle underlining throughout the book of the father's declining mentality or if not
# Start Time: 17:12
# ----------
# SnippetL: necessarily a decline, a rejection of the state he finds himself in. I believe the father here knew that this was a senseless act, but it was an act
# Start Time: 17:19
# ----------
# SnippetL: nonetheless and one that he could do. In a world where so much agency was ripped from him, it's been a while since he picked up a phone and called his dad's
# Start Time: 17:27
# ----------
# SnippetL: house. And of course, there's the obvious connection between him being the father now and trying to call someone who will never pick up, someone who was
# Start Time: 17:35
# ----------
# SnippetL: a father to him. They get a little bit away from the gas station before the father remarks that they're being sloppy. There's more stuff they could have salvaged from there that other
# Start Time: 17:42
# ----------
# SnippetL: people have left. So, they go back, take all the empty oil quarts, and turn them upside down into one oil jug. By the time they're done, they have a half
# Start Time: 17:50
# ----------
# SnippetL: quart of motor oil. Oil that they can use for their campsite lantern. The boy remarks that this means his dad can read him a story tonight. Obviously, the most human element of the book is the boy.
# Start Time: 17:58
# ----------
# SnippetL: He's a picture of innocence in a world that's long since forgotten. So, because of that, moments like that, where the boy is excited in the midst of everything that his dad gets to read him
# Start Time: 18:09
# ----------
# SnippetL: at bedtime story is refreshing, but stands in almost comedic contrast to the world around him. And moments like that further emphasize to us what the father
# Start Time: 18:17
# ----------
# SnippetL: sees in him. Even if you're at your wits end and want it all to be over, if your son asked you to read a story, how could you not keep pushing on? For the two, it
# Start Time: 18:26
# ----------
# SnippetL: seems that every night is a fight against the elements. The world is cold in the day, and it is freezing at night.
# Start Time: 18:34
# ----------
# SnippetL: Add to this that rainstorms seem to be near constant. They keep tarps with them to lay over top of them as they sleep curled into each other. Being too cold
# Start Time: 18:40
# ----------
# SnippetL: can be a problem, but being too cold and wet is dangerous. So, in one of their first nights, when they see it beginning to rain, they put a tarp over the
# Start Time: 18:49
# ----------
# SnippetL: shopping cart and make their way to a large rock. Grilling up in the dry dirt under the rock for the night. In the deep dark, the boy asks if it's okay if
# Start Time: 18:57
# ----------
# SnippetL: they can leave the lamp on for a little bit. To which the father replies, "Yes,
# Start Time: 19:05
# ----------
# SnippetL: of course, we can." Logically, this doesn't make any sense. They need to conserve their resources. But to the father, what point is there beyond making his son comfortable? That night,
# Start Time: 19:09
# ----------
# SnippetL: laying in the dark under the stone, the two have this conversation. He was a long time going to sleep. After a while,
# Start Time: 19:18
# ----------
# SnippetL: he turned and looked at the man. His face in the small light stre with black from the rain like some old world thespian. "Can I ask you something?" he
# Start Time: 19:24
# ----------
# SnippetL: said. "Yes, of course." "Are we going to die?" "Sometime. Not now." "And we're
# Start Time: 19:34
# ----------
# SnippetL: still going south?" "Yes." So, we'll be warm. Yes. Okay.
# Start Time: 19:42
# ----------
# SnippetL: Okay. For what? Nothing. Just Okay. Go to sleep. Okay. I'm going to blow out the lamp. Is that okay?
# Start Time: 19:50
# ----------
# SnippetL: Yes, that's okay. And then later in the darkness, can I ask you something?
# Start Time: 20:00
# ----------
# SnippetL: Yes, of course you can. What would you do if I died? If you died, I would want to die, too.
# Start Time: 20:09
# ----------
# SnippetL: So you could be with me? Yes. So I could be with you. Okay.
# Start Time: 20:18
# ----------
# SnippetL: This is what I mean by most of the dialogue feels like what it would be,
# Start Time: 20:26
# ----------
# SnippetL: just reassurances. The boy afraid that they're going to die and the father correcting him and then saying that if the boy were to die, his father would be right behind him to make sure he's safe.
# Start Time: 20:29
# ----------
# SnippetL: There's a few moments that most often happen after the father and son have a conversation where it seems McCarthy
# Start Time: 20:38
# ----------
# SnippetL: kind of muses on the nature of this all semi from the father's perspective but also semi from some greater omnisient
# Start Time: 20:45
# ----------
# SnippetL: narrator's perspective. Like here's the first one after that conversation. He lay listening to the water drip in the woods bedrock. This the cold and the
# Start Time: 20:53
# ----------
# SnippetL: silence. The ashes of the late world carried on the bleak and temporal winds to and fro in the void. Carried forth and scattered carried forth again.
# Start Time: 21:03
# ----------
# SnippetL: Everything uncoupled from its shoring unsupported in the ash and air sustained by a breath trembling brief.
# Start Time: 21:14
# ----------
# SnippetL: If only my heart were stone.
# Start Time: 21:23
# ----------
# SnippetL: See, otherwise this could just be descriptions of the world. But that use of my at the end is interesting because the book is written from a third person omnisient perspective. Sure, we're with
# Start Time: 21:27
# ----------
# SnippetL: the father and son the whole time, but neither of them are the ones telling the story. The story is about the two of them, not from one of the two of them.
# Start Time: 21:35
# ----------
# SnippetL: Now, you could say perhaps this final sentence, if only my heart were stone,
# Start Time: 21:43
# ----------
# SnippetL: is just something the father saying to himself. But it's here where McCarthy's lack of punctuation almost becomes an agent within the story. Because if there
# Start Time: 21:47
# ----------
# SnippetL: were quotation marks, we'd know for sure if this was the narrator speaking or if this was the father speaking. But because we don't have that, everything's
# Start Time: 21:55
# ----------
# SnippetL: drawn into question. Is this entire paragraph the father thinking to himself? Is this instead McCarthy as the narrator having his heart break over the
# Start Time: 22:03
# ----------
# SnippetL: notion of this situation? I also find the language used in that paragraph to be interesting. The description that everything is uncoupled, untethered from
# Start Time: 22:11
# ----------
# SnippetL: its shoring. I mean, the world's been made into ash. ash that's in the air that floats around with your breath is from every part of the world all at once. It describes the air as
# Start Time: 22:19
# ----------
# SnippetL: unsupported, trembling, and brief and then says, "I wish my heart was stone."
# Start Time: 22:28
# ----------
# SnippetL: Drawing the connection between someone's heart and the world around it. Again,
# Start Time: 22:32
# ----------
# SnippetL: this could all be from the father's perspective, but it also points to the idea that perhaps there's something greater at play. I won't necessarily say
# Start Time: 22:36
# ----------
# SnippetL: the supernatural, but the story certainly has hintings of a power, of some force, of some agency, of some
# Start Time: 22:43
# ----------
# SnippetL: design. I mean, that was kind of defined by the father's commission. If the boy were not the word of God, then God never spoke. Meaning, God or something godlike
# Start Time: 22:51
# ----------
# SnippetL: must be out there that gave this child to this man. It's not an accident that he is here to protect him. Because of
# Start Time: 22:59
# ----------
# SnippetL: that, moments like this where we get these musings or we get these little descriptors, especially after the father and son speak almost feel like they're coming from God or something godlike.
# Start Time: 23:06
# ----------
# SnippetL: That whatever power exists in the universe, whatever power put these two together is watching them. Some sense we are reading a book and this might as
# Start Time: 23:17
# ----------
# SnippetL: well be the narrator, right? But it seems that nearly the narrator is a part of the story that there is some force watching them and his heart breaks for
# Start Time: 23:25
# ----------
# SnippetL: the boy and the father. This idea of a greater agency will be touched on more as we go along. But for now, it seems they've come to the same conclusion we
# Start Time: 23:33
# ----------
# SnippetL: have. What a horrible thing for a son to have to ask his father. And immediately after this, it seems that the father has his own questions for this higher power
# Start Time: 23:40
# ----------
# SnippetL: as well. He woke before dawn and watched the gray day break. Slow and half opaque. He rose while the boy slept and
# Start Time: 23:49
# ----------
# SnippetL: pulled on his shoes and wrapped in his blanket, he walked out through the trees. He descended into a gri in the stone and there he crouched coughing. He
# Start Time: 23:57
# ----------
# SnippetL: coughed for a long time. Then he just knelt in the ashes. He raised his face to the paling day.
# Start Time: 24:06
# ----------
# SnippetL: "Are you there?" he whispered. "Will I see you at last? Have you a neck by which to throttle you? Have you a heart?
# Start Time: 24:14
# ----------
# SnippetL: Damn you eternally. Have you a soul?"
# Start Time: 24:23
# ----------
# SnippetL: "Oh, God," he whispered. "Oh, God." If the story wasn't depressing enough,
# Start Time: 24:26
# ----------
# SnippetL: we're now dealt another crushing reality. Dad's dying. The worst part about it is he knows it. His boy can't be more than eight, maybe 9 years old.
# Start Time: 24:31
# ----------
# SnippetL: This world is harsh and violent, and it's kill or be killed. And the father knows that if he's gone, what chance does his son have? So, he makes his
# Start Time: 24:40
# ----------
# SnippetL: appeal to heaven and it's one out of anger. Not to stave off his own death for his sake. If it were up to him,
# Start Time: 24:48
# ----------
# SnippetL: that'd probably be something comforting by now. But the misery that he must die for his son's sake, crying out to God,
# Start Time: 24:54
# ----------
# SnippetL: saying, "If he has a throat, he'll choke him. And if he could damn him, he would." From his perspective, it seems to be a cruel joke. God commissioned him
# Start Time: 25:00
# ----------
# SnippetL: to take care of this boy. Now he's going to take him out of the picture before he can. The two of them walk through the next day and come across a burned city.
# Start Time: 25:08
# ----------
# SnippetL: Nothing to scavenge as all has been made to ash. These fires, whatever they came from, swept up forests, cities, roads,
# Start Time: 25:15
# ----------
# SnippetL: cars, and people. As they're walking through the streets, they see the bodies of many, charred and dried. In the midst of this, he pulls the boy into him and
# Start Time: 25:22
# ----------
# SnippetL: says, "The things you put into your head are there forever." The boy asks, "You forget some things, don't you?" And the father says, "Yes, you forget what you
# Start Time: 25:30
# ----------
# SnippetL: want to remember, and you remember what you want to forget." Immediately after this, we get a flashback of the father's life, something the father would probably want to forget. It's just a
# Start Time: 25:38
# ----------
# SnippetL: simple description of a day he and his uncle went out to collect firewood. They went out on a boat, collected firewood,
# Start Time: 25:47
# ----------
# SnippetL: and relaxed on the lake afterwards. It was a quiet day, but at the end it says,
# Start Time: 25:52
# ----------
# SnippetL: "This was the perfect day of his childhood. This the day to shape the days upon." This memory works twofold for the father. Well, normally you may
# Start Time: 25:56
# ----------
# SnippetL: think memories of the good times are a relief, something to hold on to. But in a world like this, that lake isn't there anymore. His uncle isn't there anymore,
# Start Time: 26:04
# ----------
# SnippetL: and days like that are never coming back. So, in contrast, now it's almost like a ghost that haunts him. something so perfect that he'll never see again.
# Start Time: 26:12
# ----------
# SnippetL: And to the boy, it's something unfathomable. We'll learn later that the boy was born after the world came to be this. Things like that, things like
# Start Time: 26:21
# ----------
# SnippetL: relaxing or collecting firewood or times of leisure are just ideas. It shows a dissonance between the father and son,
# Start Time: 26:30
# ----------
# SnippetL: but also a misery for the father. The boy is unbburdened by things he wants to forget. The world simply is. There is no greater point to try to go back to or
# Start Time: 26:37
# ----------
# SnippetL: one to sulk over. Perhaps the reason he can keep his humanity is because he's unbburdened by the idea of a greater one. The two of them continue south.
# Start Time: 26:46
# ----------
# SnippetL: Regardless of their direction, things are getting colder. So cold that the father falls asleep clutching his son,
# Start Time: 26:54
# ----------
# SnippetL: counting his breaths in the night. The story remarks that if they got any rain on them, they'd probably die. I know a lot of what I'm doing here is talking
# Start Time: 27:00
# ----------
# SnippetL: about narrative moments where things change in the story or quote unquote important moments of reflection, but I
# Start Time: 27:08
# ----------
# SnippetL: also don't want it to be lost how impressive some of McCarthy's writing is. Again, I highly recommend you get the book for yourself and experience it firsthand. But to give you an idea,
# Start Time: 27:15
# ----------
# SnippetL: there's so many passages that sound like this. The blackness he woke to on those nights was sightless and impenetrable. a blackness to hurt your eyes with
# Start Time: 27:26
# ----------
# SnippetL: listening. Often he had to get up. No sound but the wind and the bare and blackened trees. He rose and stood
# Start Time: 27:35
# ----------
# SnippetL: tottering in that cold autistic dark with his arms out held for balance while the vestibular calculations in his skull cranked out their reckonings. An old
# Start Time: 27:43
# ----------
# SnippetL: chronicle to seek out the upright. No fall but proceeded by declination.
# Start Time: 27:52
# ----------
# SnippetL: He took great marching steps into the nothingness, counting them against his return. Eyes closed, arms or upright to what? Something nameless in the night.
# Start Time: 27:59
# ----------
# SnippetL: Load or matrix to which he and the stars were common satellite like the great pendulum in its rotunda describing
# Start Time: 28:11
# ----------
# SnippetL: through the long day movements of the universe of which you may say it knows nothing and yet know it must. It's just
# Start Time: 28:19
# ----------
# SnippetL: such beautiful poetry describing his movements through a darkness that he might as well shut his eyes to keep his bearings to not trick his mind to try to
# Start Time: 28:26
# ----------
# SnippetL: bring in another sense it's not going to get anything from. And it describes him moving in this way as some device from the stars. Something looking for a
# Start Time: 28:35
# ----------
# SnippetL: greater uprightness that seems etched into the cosmos. All this to describe a man stumbling through the dark. In the midst of this misery, the boy is still
# Start Time: 28:43
# ----------
# SnippetL: being a boy. They have masks they wear over their face to keep them from breathing in too much ash, which, you know, is a relative statement. And the
# Start Time: 28:51
# ----------
# SnippetL: boy drew fangs on his because he's a kid and he thinks it looks cool. As they're walking, one day it begins to snow.
# Start Time: 28:58
# ----------
# SnippetL: Previously, he would set up in the morning and look with binoculars to see any smoke rising from some distant fire,
# Start Time: 29:05
# ----------
# SnippetL: but here it seems there are none. The story says he thought the blood cults must have all consumed one another. No one traveled this road. No road agents,
# Start Time: 29:11
# ----------
# SnippetL: no marauders, blood cults. What do you mean blood cults and marauders? Well, as you can imagine, in a world as rough as
# Start Time: 29:20
# ----------
# SnippetL: this, those that have stayed alive have done so through mostly terrible means.
# Start Time: 29:28
# ----------
# SnippetL: Again, it's something further that separates the father and son from the world around them. It also points to why the father always keeps the gun on his belt. Because if someone's alive for this long, there's probably a reason.
# Start Time: 29:32
# ----------
# SnippetL: They come to an old garage and the father fix a squeaky wheel on their shopping cart. As he uses a saw and bolts and screws, the story says that the boy set watching his every move.
# Start Time: 29:43
# ----------
# SnippetL: Everything that the father does, the boy takes in. Again, he's his whole world.
# Start Time: 29:52
# ----------
# SnippetL: After leaving the garage, the story says, "In the morning, they went on desolate country. A borehide nailed to a
# Start Time: 29:56
# ----------
# SnippetL: barn door. Ratty wisp of a tail. Inside the barn, three bodies hanging from the rafters.
# Start Time: 30:04
# ----------
# SnippetL: tried and dusty among the wand slats of light. There could be something here,
# Start Time: 30:13
# ----------
# SnippetL: boy said. There could be some corn or something. Let's go, the man said. It's one of many times in the story we will
# Start Time: 30:18
# ----------
# SnippetL: see the aftermath of some tragedy. We don't know why these three people were hung in the barn, but it's probably over something that doesn't matter now. The
# Start Time: 30:27
# ----------
# SnippetL: world is graffitied in these little moments of violence. the final image or the standing portrait of moments of hatred or moments of anger. All around
# Start Time: 30:34
# ----------
# SnippetL: the two of them, humanity has presented their epitap of agony. And once again,
# Start Time: 30:43
# ----------
# SnippetL: it's the contrast to this that make a little boy drawing fangs on his mask all the more special. Not despite the violence around them, but because of it,
# Start Time: 30:48
# ----------
# SnippetL: it makes him sacred. As you can imagine,
# Start Time: 30:57
# ----------
# SnippetL: one of the most precious resources to them is food. They have a few provisions that they ration out, but it's hard to scavenge anything. I mean, obviously,
# Start Time: 30:59
# ----------
# SnippetL: when the world began to fall apart,
# Start Time: 31:07
# ----------
# SnippetL: people took what they could, but then anything that wasn't taken then has been taken over the several years of people traveling the same road. As you could
# Start Time: 31:08
# ----------
# SnippetL: imagine, they're always hungry. But the father always finds just enough to keep them alive. At night, when he's not making sure the boy is breathing, the
# Start Time: 31:16
# ----------
# SnippetL: man is tormented, not only by his own paranoia. At one point, it says he thinks he hears bulrums out in the hills for a moment before the sound is gone,
# Start Time: 31:23
# ----------
# SnippetL: but by things he sees in his dreams,
# Start Time: 31:31
# ----------
# SnippetL: things he probably wishes he could forget. In his dreams, his pale bride came to him out of a green and leafy canopy. Her nipples pipe clay and her
# Start Time: 31:33
# ----------
# SnippetL: ribbones painted white. She wore a dress of gauze and her dark hair was carried up in combs of ivory, combs of shell.
# Start Time: 31:42
# ----------
# SnippetL: Her smile, her downturned eyes. In the morning, it was snowing again. Beads of small gray eyes strung along the light wires overhead.
# Start Time: 31:50
# ----------
# SnippetL: He mistrusted all of that. He said the right dreams for a man in peril were dreams of peril and all else was the call of langor and of death. He slept
# Start Time: 32:00
# ----------
# SnippetL: little and he slept poorly. He dreamt of walking in a flowering wood where birds flew before them. He and the child and
# Start Time: 32:09
# ----------
# SnippetL: the sky was aching blue, but he was learning how to wake himself from just such siren worlds. Lying there in the dark with the uncanny taste of a peach
# Start Time: 32:18
# ----------
# SnippetL: from some phantom orchard fading in his mouth. He thought if he lived long enough, the world at last would all be lost.
# Start Time: 32:27
# ----------
# SnippetL: Like the dying world the newly blind inhabit. All of it slowly fading from memory.
# Start Time: 32:35
# ----------
# SnippetL: From daydreams on the road, there was no waking plotted on. He could remember everything of her save her scent. Seated in the theater with her beside him,
# Start Time: 32:41
# ----------
# SnippetL: leaning forward, listening to the music,
# Start Time: 32:51
# ----------
# SnippetL: gold scroll work and scones and the tall columner folds of the drapes at either side of the stage. She held his hand in her lap and he could feel the tops of
# Start Time: 32:54
# ----------
# SnippetL: her stockings through the thin stuff of her summer dress. Freeze this frame. Now call down your dark and your cold and be
# Start Time: 33:03
# ----------
# SnippetL: damned. As you could imagine, if he is a father and this is his son, then at one point there was a woman. A woman who is gone now, but one who visits him in his
# Start Time: 33:10
# ----------
# SnippetL: dreams. In his dreams, he sees her as something goddy, something apart from the world he's in now. and the dreams of her in combination with the dreams of
# Start Time: 33:19
# ----------
# SnippetL: bright blue summer days of birds of him with his son. All of these are siren calls. Something luring him to the other side of death. Something unobtainable
# Start Time: 33:27
# ----------
# SnippetL: with the life and body he has now. But even in the day, he can't stop thinking of her. Can't stop thinking of dates they had at theaters. Moments of joy, of
# Start Time: 33:36
# ----------
# SnippetL: boyhood, of love that are all extinct now. And he's simply the last dinosaur that remembered what all the others look like. Again, all of this paints the
# Start Time: 33:44
# ----------
# SnippetL: misery of everything. All the things that we know to be moments of joy, moments we look forward to don't exist.
# Start Time: 33:52
# ----------
# SnippetL: But McCarthy counters that with what the father does with his son. He fashioned sweeps from two old brooms he'd found and wired them to the cart to clear the
# Start Time: 33:59
# ----------
# SnippetL: limbs from the road in front of the wheels and stood on the rear rail like a dog musher. And they set off down the hills, guiding the cart on the curves
# Start Time: 34:06
# ----------
# SnippetL: with their bodies in the manner of bobslutters. It was the first that he'd seen the boy smile in a long time.
# Start Time: 34:14
# ----------
# SnippetL: Similar to what I said earlier, the perfect day that haunts the father. To the boy, this might as well be the perfect day. Things like joy and hope
# Start Time: 34:19
# ----------
# SnippetL: only exist in him. And in a world drained of those things, it's like the father is transporting the cure across a diseased wasteland. The boy is special
# Start Time: 34:27
# ----------
# SnippetL: because he is the boy. What else is there? While walking, the father and son come to an old dam, and the father explains to the son how dams work. It's
# Start Time: 34:36
# ----------
# SnippetL: worth pointing out here that we're never told explicitly the route the father and son take, but there are certainly clues that give us a pretty good idea. I mean,
# Start Time: 34:44
# ----------
# ...
# Start Time: 3:46:47
# ----------
# SnippetL: who talked to him about her father, seem protected, they seem strong. There's a boy his age and a girl his age as well.
# Start Time: 3:46:54
# ----------
# SnippetL: Everything went so right for the boy in ways his father couldn't imagine. A future unimaginable. And then there's
# Start Time: 3:47:00
# ----------
# SnippetL: one final paragraph that closes out the novel. Once there were brook trout in the streams in the mountains. You could see them standing in the amber current
# Start Time: 3:47:07
# ----------
# SnippetL: where the wide edges of their fins wimpled softly in the flow. They smelled of moss in your hand, polished,
# Start Time: 3:47:16
# ----------
# SnippetL: muscular, torsional.
# Start Time: 3:47:23
# ----------
# SnippetL: On their backs were vermiculate patterns that were maps of the world and its becoming. Maps and mazes of a thing which could not be put back,
# Start Time: 3:47:25
# ----------
# SnippetL: not be made right again. In the deep glenns where they lived, all things were older than man. They hummed of mystery.
# Start Time: 3:47:36
# ----------
# SnippetL: And with that, we have the conclusion of Cormick McCarthy's The Road. There's a lot of ways to talk about this book, but
# Start Time: 3:47:44
# ----------
# SnippetL: I think the one that is the most fitting given my reaction and current emotional state is my personal takeaway and what I think the core of this book really is.
# Start Time: 3:47:52
# ----------
# SnippetL: As I talked about throughout this video,
# Start Time: 3:48:01
# ----------
# SnippetL: this is a book that I feel so attached to. It's a father from Appalachia writing a book dedicated to his son.
# Start Time: 3:48:03
# ----------
# SnippetL: Cormick's son and I were born in the same year. He wrote this story about the place I grew up around. The sites and things he described are things I grew up
# Start Time: 3:48:11
# ----------
# SnippetL: with. And it's this story as well as many of his others that pushed me to have a love for storytelling, to have a love for storytelling that I want to
# Start Time: 3:48:18
# ----------
# SnippetL: start a YouTube channel. This book has always had deep personal connection with me, but now that I'm a father, it means
# Start Time: 3:48:26
# ----------
# SnippetL: all the more. The beginning of the video, I spoke how our English teacher introduced this book to the class is something that was deeply personal to
# Start Time: 3:48:33
# ----------
# SnippetL: him. And I remember he told the story that when McCarthy's son was born, and again I don't know if this is true or
# Start Time: 3:48:41
# ----------
# SnippetL: not, but this is what I've been told. He said that when McCarthy's son was born,
# Start Time: 3:48:48
# ----------
# SnippetL: in an interview, McCarthy said that he held his child in the hospital and he looked out over a gray sky and imagined
# Start Time: 3:48:52
# ----------
# SnippetL: that if it came to it, he would do whatever it took to get his son through this world, whatever that world may look like. And that idea flourished to what
# Start Time: 3:48:59
# ----------
# SnippetL: the road became. And when my child was born, I was standing at the hospital window and I looked out on the horizon and there was a storm over the
# Start Time: 3:49:07
# ----------
# SnippetL: mountains. And in that moment, I remembered the story my English teacher told me of McCarthy and thought to myself, "Of course, who wouldn't?" And
# Start Time: 3:49:14
# ----------
# SnippetL: now, since being a father, I read this book again and it meant something different this time. From the beginning of the book, the father is set to die.
# Start Time: 3:49:24
# ----------
# SnippetL: One of the first things we learn about him is that he can't stop coughing and he's coughing up blood. From the opening pages, his mortality is made known. From
# Start Time: 3:49:32
# ----------
# SnippetL: the opening pages, the only thing that matters is the boy. The father does not know where the road ends. He doesn't know where they're going to end up, and
# Start Time: 3:49:39
# ----------
# SnippetL: he doesn't know what's going to become of the son. But all he can do is instill and stoke the fire within his son. I think something that McCarthy felt when
# Start Time: 3:49:47
# ----------
# SnippetL: he wrote this book, and something that I'm starting to feel now, is from the opening pages, I'm not going to be around for the last ones. The road goes
# Start Time: 3:49:55
# ----------
# SnippetL: on forever. I don't know how it's going to end up, but I do know that goodness will find the boy. The road is one of the most hopeful stories I've ever read.
# Start Time: 3:50:02
# ----------
# SnippetL: Drives me up a wall when people talk about this story being depressing and empty and sad. Like, sure, that was what
# Start Time: 3:50:13
# ----------
# SnippetL: the world around them was, but that's not what the story was. The story was of a father who saw his son as the voice of God. A tabernacle floating in the middle
# Start Time: 3:50:21
# ----------
# SnippetL: of a wasteland. A boy so important that the gods are watching to make sure that he is taken care of. What a hopeful message. The idea that love carries on
# Start Time: 3:50:30
# ----------
# SnippetL: after death, that so much hope and cherishment is around this one child that the world will bend over backwards to make sure he's secure. I mean,
# Start Time: 3:50:39
# ----------
# SnippetL: throughout the story, there were so many instances of divine providence. Right when they're about to freeze going over the mountains, they reach the break in the gap. Right when the father begins to
# Start Time: 3:50:47
# ----------
# SnippetL: become hopeless, they come across the old man. the countless number of times they came across food at the final second, especially the bunker. Even
# Start Time: 3:50:56
# ----------
# SnippetL: apples, an extinct fruit that spring up out of the ground to make sure the boys taken care of. What a beautiful idea that this love, this bond is something the world can't take away from them,
# Start Time: 3:51:03
# ----------
# SnippetL: regardless of how evil it becomes.
# Start Time: 3:51:14
# ----------
# SnippetL: Because that several of the themes of the book are applicable to the real world. Yes, the world does have terrible things in it. Yes, things will be bad,
# Start Time: 3:51:16
# ----------
# SnippetL: but that doesn't mean the fire doesn't exist. that doesn't mean it's not worth pushing on. From our opening lines of the story, the father says this is his
# Start Time: 3:51:23
# ----------
# SnippetL: commission from God to take care of this child. And in the final lines of the story, the woman tells the boy that his father might as well have been the voice of God. I mean, what would God have done
# Start Time: 3:51:31
# ----------
# SnippetL: if not take care of him? And that through history, there were people who carried the fire, people who were the voice of God, passing on goodness to their sons and daughters. God and his
# Start Time: 3:51:39
# ----------
# SnippetL: oracles watched over them from the outset of their journey. And along the way, anytime it was too hard, it was made right again. And ultimately, when
# Start Time: 3:51:48
# ----------
# SnippetL: the father wasn't there to watch him, he sent his angels into the picture.
# Start Time: 3:51:56
# ----------
# SnippetL: Whatever higher power exists in this universe had to be sure that the fire made it out. Because regardless of time, regardless of what state the world is,
# Start Time: 3:51:59
# ----------
# SnippetL: whether it be right now or in a post-apocalypse, what else matters? I think this idea of divinity, of some grand design, is perfectly encapsulated in that final paragraph in the book.
# Start Time: 3:52:07
# ----------
# SnippetL: talks about how there were trout that were in the mountains. That on the speckles of their back, the mazes and maps of the world were predestined long
# Start Time: 3:52:18
# ----------
# SnippetL: before humanity got there. Long before we knew to look, it was already written out. The world may be a maze. It may be treacherous and it may be scary. And a
# Start Time: 3:52:26
# ----------
# SnippetL: lot of us won't be around for the end of it, but in the end, goodness finds the boy. Cormick McCarthy ties a lot of themes from one of his stories into the
# Start Time: 3:52:34
# ----------
# SnippetL: next. And the story that he wrote before he wrote The Road was No Country for Old Men. originally developed as a screenplay and then as a novel. I talked
# Start Time: 3:52:42
# ----------
# SnippetL: about this in one of the earliest videos in my channel, but at the end of No Country for Old Men, the sheriff has a dream of his father riding on horseback
# Start Time: 3:52:50
# ----------
# SnippetL: through the mountains. And in that dream, Sheriff Bell says he saw his father carrying a fire out into the dark, out into the cold. That symbolism
# Start Time: 3:52:58
# ----------
# SnippetL: has its own weight in that story, but it's so clear how it's applied to this one. Our fathers and their fathers and their fathers before them all carried the fire. Now, in a world of misery,
# Start Time: 3:53:07
# ----------
# SnippetL: especially when there's misery and monsters and things that go bump in the night, who are we to make sure that the torch doesn't keep going? And if that
# Start Time: 3:53:17
# ----------
# SnippetL: fire is so important, if it's so important that it bends the voice and ear of God, then how could goodness not find it? The road is not hopeful in spite of its setting, but because of it.
# Start Time: 3:53:24
# ----------
# SnippetL: In a world so miserable, so close to humanity's extinction, the same thing that matters is what's always mattered.
# Start Time: 3:53:35
# ----------
# SnippetL: The carriers of something so sacred will always be sacred, or especially in a world that's forgot what that means.
# Start Time: 3:53:42
# ----------
# SnippetL: It's for these reasons that The Road is my favorite book. Not only is it an interesting setting with interesting characters and dialogues and themes, but
# Start Time: 3:53:48
# ----------
# SnippetL: it so perfectly executes those uses the theme of fire, the father and son looking out for each other, and it
# Start Time: 3:53:57
# ----------
# SnippetL: weaves all of those into this idea of a grander purpose of walking through misery, but with something that matters.
# Start Time: 3:54:04
# ----------
# SnippetL: It's a book about endurance, about purpose, about love and hope. And it's a story that I appreciate more every time I come back to it. Like I said, it's one
# Start Time: 3:54:10
# ----------
# SnippetL: I've been nervous to cover because it means so much to me. But hopefully I was able to get that across at least a little bit and do the story some
# Start Time: 3:54:19
# ----------
# SnippetL: justice. And hopefully you've read the story first and didn't let this be your first experience. But even if you did that, hopefully now it means something to you. The Road is one of those books
# Start Time: 3:54:27
# ----------
# SnippetL: that I think a lot of people have heard of, but not as many have read. Sure, in older generations and in times past, I mean, it's incredibly famous book. A lot
# Start Time: 3:54:35
# ----------
# SnippetL: of people have read it, but its reputation certainly exceeds it. But as with any other McCarthy story, I think it's one worth reading and one worth dwelling on. So hopefully you guys
# Start Time: 3:54:43
# ----------
# SnippetL: enjoyed it. Hopefully this all meant something to you. And I just want to say thank you for watching. There are some other adaptations of The Road that I think are interesting. For example,
# Start Time: 3:54:52
# ----------
# SnippetL: there's the visual novel uh that was illustrated by Manu Larsenette. I have a copy of that and it's pretty cool for visualizing a lot of the things in the
# Start Time: 3:55:00
# ----------
# SnippetL: book. If you're a fan of the book, I highly recommend it. And there's also the John Hillcoat film that's pretty good. Uh VGO Mortonson does a fantastic
# Start Time: 3:55:07
# ----------
# SnippetL: job playing the father. Uh the movie has now sadly late and great Robert Duval in it playing the old man. But while it's
# Start Time: 3:55:15
# ----------
# SnippetL: good and John Hill was the director of it, he's the guy who's currently slated to direct Blood Meridian. So, you know,
# Start Time: 3:55:23
# ----------
# SnippetL: I want to hype that guy up because I want that movie to be good. There's so much you have to change from a literary
# Start Time: 3:55:29
# ----------
# SnippetL: to a visual adaptation of the story that while it's good, I don't think it really holds a candle to the book. Just cuz I
# Start Time: 3:55:36
# ----------
# SnippetL: mean, how in a movie do you portray the instances of the writer almost coming out of the page to speak to the father and to speak to the reader or these
# Start Time: 3:55:42
# ----------
# SnippetL: musings the father has to himself evoking everything from Job when he says, "Curse God and die to muses to old
# Start Time: 3:55:51
# ----------
# SnippetL: epics." I mean, the book itself really feels like another odyssey. You have the father and son traveling on this long voyage, coming across sights and horrors
# Start Time: 3:55:58
# ----------
# SnippetL: as they go. And you get some of that when you watch the film, but you don't really get the choir part of it, right?
# Start Time: 3:56:07
# ----------
# SnippetL: The part where the story reminisces or really brings up its themes that enhance everything else you're reading. It's just a piece that's so perfectly adapted
# Start Time: 3:56:13
# ----------
# SnippetL: to a novel that it's hard for me to see how you could even translate it to a visual format. As a matter of fact,
# Start Time: 3:56:22
# ----------
# SnippetL: here's a hot take. I honestly think a Blood Meridian adaptation would hypothetically do better than a road adaptation because a lot of the things
# Start Time: 3:56:29
# ----------
# SnippetL: in Blood Meridian are moments of dialogue or visuals that are described.
# Start Time: 3:56:37
# ----------
# SnippetL: These are things that can be illustrated on screen, whereas a lot of the stuff in the road is internal monologues or thoughts or sometimes the book musing on
# Start Time: 3:56:41
# ----------
# SnippetL: what's happening. So again, I don't hate the movie. I think it's pretty cool. If you're a fan of the book, it's certainly worth watching. But yeah, if you couldn't tell, there's not really
# Start Time: 3:56:49
# ----------
# SnippetL: anything that beats this for me. All in all, I've talked for long enough. I hope you guys enjoyed this video. There will be new videos on the way soon. I
# Start Time: 3:56:57
# ----------
# SnippetL: promise. Being a father now has caused quite a change in my daily routine, so forgive me if I'm a little behind on some stuff, but hopefully it'll be worth
# Start Time: 3:57:04
# ----------
# SnippetL: it when it comes out. And hopefully this video was worth it. I'm certainly nervous and can't wait for everyone to rip me apart for talking about this
# Start Time: 3:57:12
# ----------
# SnippetL: story, but oops. They can say I'm bad at literary analysis. They can say I shouldn't be talking about these stories, but what they can't say is I don't got the gumption for it. I mean,
# Start Time: 3:57:19
# ----------
# SnippetL: they could say that, but that's probably like the third or fourth thing they'll pick. All in all, I believe that should do it for now. But before I go, I just want to say thank you for watching. I
# Start Time: 3:57:30
# ----------
# SnippetL: hope that you enjoyed, especially on a video that means so much to me, and I'll see you in the next one. [snorts] Bye.
# Start Time: 3:57:38
# ----------
# SnippetL: Or not really. The video means so much to me. I mean, this is a video I made.
# Start Time: 3:57:47
# ----------
# SnippetL: The story I made the video about means so much to me. Not my own video. That sounds pretentious, which I am a
# Start Time: 3:57:51
# ----------
# SnippetL: YouTuber, so you know, fair enough.
# Start Time: 3:57:59
# ----------

# %%
with open('transcript.txt', 'w') as f:
    for result in response.get("transcript", []):
        snippet = result.get("snippet")
        if snippet:
            f.write(f"{snippet}\n")

print("Results saved to transcript.txt")
# Out:
# Results saved to transcript.txt

# %%
#What went well?
# - Everything went well, did not have any problems.
#What did not go well or what challenges you encountered?
# - I did not have any challenges, everything went smoothly.
